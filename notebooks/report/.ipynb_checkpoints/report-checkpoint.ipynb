# %% [markdown]
# <p align="center">
#   <br/>
#   <img src="medias/genyus-logo.png" width="150px">
#   <br/>
#   <br/>
#   <h1 align="center">
#     <p align="center">
#       Owen Gombas<br/>
#       Darmanger David
#     </p>
#   </h1>
#   <h2 align="center">
#     <p align="center">
#       Juin 2021
#     </p>
#   </h2>
#   <br/>
# </p>
#
# # Table des matières
#
#     1. INTRODUCTION
#         1.1 But
#         1.2 API et services utilisés
#         1.3 Modules complémentaires
#         1.4 Statistiques principales
#
#     2. CORPS DU TRAVAIL
#         2.1 Traitement et analyse de la liste des musiques avant récupération
#         2.2 Récupérations des informations des musiques
#         2.3 Le scraping de données
#         2.4 Scraping des données
#         2.5 Clean des sons après récupération
#         2.6 Créations de plusieurs champs dérivés des paroles originales
#         2.7 Analyses des mots avec des dictionnaires de langue
#
#     3. STATISTIQUES SUR L'UTILISATION DES MOTS
#         3.1 Recherche d'un mot particulier et pourcentage
#         3.2 Les mots ne figurant pas dans le dictionnaire français (ni anglais)
#         3.3 Les anglicismes
#         3.4 Le "vrai" français
#         3.5 Répartitions du langage
#
#     4. STATISTIQUES SUR LES ARTISTES
#         4.1 Regroupements des musiques par artistes
#         4.2 Représentations des pertes dues au nettoyage des musiques au niveau des artistes
#         4.3 Calculs du pourcentage de répétition
#         4.4 Classement des artistes se répétant du moins au plus
#
#     5. STATISTIQUES DANS LE TEMPS
#         5.1 Regroupement des mots par années
#         5.2 Représentations du nombre de nos musiques par année
#         5.3 Affichages de l'utilisation d'un mot par années
#
#     6. LIMITATIONS ET PERSPECTIVES
#
#     7. CONCLUSION

# %% [markdown]
# # 1. INTRODUCTION
#
# ## 1.1 But
#
# C’est dans le cadre de notre cours de python (1242.4 PYTHON) que nous avons effectué ce projet. L’objectif du travail était de prendre en main le langage python et d’avoir une première introduction à l’analyse de données grâce aux outils fournis par le langage. Mais également une prise en main de l’utilisation de notebooks jupyter pour la mise en place du projet.
#
# En ce qui concerne le travail en lui-même, notre projet est un outil d’analyse du “vocabulaire” utilisé dans le rap francophone. Pour être plus précis, on va analyser les paroles d’un échantillon de chansons de rap francophones de ces 20-30 dernières années et les utiliser pour effectuer plusieurs statistiques. Nous avons dans un premier temps délibérément choisi de nous limiter uniquement à des musiques de rap, car selon nous, c'est le genre de musique qui jouit de la plus grande diversité de langage et qui a le plus évolué dans le temps durant ces dernières années.
#
# Exemples de statistiques:
#
#     1) Afficher les mots français les plus utilisés, les mots anglais les plus utilisés, mais également les mots les plus utilisés du jargon qui ne figure pas officiellement dans le dictionnaire français.
#     2) Analyse de quels artistes ont les textes les plus variés en termes de vocabulaire.
#     3) Le pourcentage d’utilisation d’un mot particulier sur l’ensemble des chansons ou encore son pourcentage d’utilisation au cours des différentes années.
#
# ## 1.2 API et services utilisés
#
# En ce qui concerne le choix de notre échantillon, nous avons effectué une playlist avec un total de 1847 titres différents pour un total de 109h50min de chanson en continu. Nous avons ensuite exporté le nom des musiques et les artistes qui leur sont associés en un fichier texte, qui sera utilisé pour la récupération des données. Une partie seulement de toutes les chansons seront utilisées en raison de l’API utilisé.
# Afin de récupérer les données nécessaires au projet, nous avons besoin de :
#
#
# ### 1) [Spotify](https://www.spotify.com/fr/)
# Grâce Spotify on va facilement pouvoir regrouper les chansons qui nous intéresse.
# La playlist utilisée dans le cadre du projet : https://open.spotify.com/playlist/3bp6rWaNssiLhZP431bkU7?si=a5f19a02267a4101
#
#
# ### 2) [Tune My Music](https://www.tunemymusic.com/fr/Spotify-to-File.php)
# Ce site permet d'exporter une playlist dans un fichier texte simple au format:
# ```
# Artist - Titre 1
# Artist - Titre 2
# Artist 2 - Titre 2.2
# ```
# ### 3) [Genius](https://genius.com)
# Genius est un site fournissant les paroles de musiques, et c'est l'API de ce site que l'on a utilisé afin d'obtenir des informations relatives à la musique.
#
# ### Fonctionnalités de l'API
# Nous avons principalement utilisé que deux fonctionnalités de l'API:
# - Recherche globale de musiques, d'artistes ou d'albums
# - Récupération des informations d'une musique, d'un artiste ou d'un album
#
# ### Récupération des paroles
# Malheureusement l'API ne nous fournit pas la possibilité d'obtenir les paroles, on va devoir "scraper" les données avec `beautifulsoup` qui est un module python.
#
# ## 1.3 Modules complémentaires
# Voici la liste des différents modules utilisés dans le projet:
#
# + numpy (via anaconda.navigator)
# + Pandas (via anaconda.navigator)
# + Matplotlib (via anaconda.navigator)
#
# Utiliser pour l’authentification avec un token à l’API genius:
# + Rauth (via terminal: `pip install rauth`)
#
# Scrapping des données:
#
# + Beautifulsoup4 (via terminal:  `pip install beautifulsoup4`)
#
# Type de graphique spécifique:
#
# + Wordcloud (via terminal: `pip install wordcloud`)
#
# Pour avoir des composants interactifs:
#
# + Node.js (via anaconda.navigator)
# + Ipywidgets (via anaconda.navigator)
#
# La liste des modules utilisés dans le projet se trouve également dans "requirements.txt". Pour les installer, lancez la commande `pip install -r requirements.txt` dans un terminal à la racine du projet avec un terminal anaconda.

# %% [markdown]
# ## 1.4 Statistiques principales
#
#
# #### Voici la liste des 50 mots français les plus utilisés dans les chansons de rap qu'on a récupérés. Nous avons représenté cette liste sous forme de "wordcloud" qui est une représentation appropriée pour ce genre de statistiques.
#
# <img src="medias/wordcloud-french.png" width="550px">
# <br>
#
# #### Voici la liste des 50 mots anglais les plus utilisés :
#
# <img src="medias/wordcloud-english.png" width="550px">
# <br>
#
# #### Voici la liste des 50 mots qui n'appartiennent pas aux dictionnaires anglais ou français. C'est donc pour la plupart des mots qui font partie du jargon. Comme "wesh", "keufs" ou encore "p'tit".
#
# <img src="medias/wordcloud-slang.png" width="550px">
# <br>
#
# #### Voici une représentation de la répartition du langage. C'est-à-dire le pourcentage d'utilisation de chaque langue/langages dans les différentes chansons de notre répertoire.
#
# <img src="medias/pie-chart-usage.png" width="400px">
# <br>
# <br>
#
#
# #### Une statistique intéressante est celle de l'utilisation d'un mot au cours du temps. Grâce à cela, on peut réellement voir l'évolution de la langue et même voir l'apparition de certains mots comme par exemple "covid" qui apparaît évidemment que ces dernières années.
#
# Exemple 1 : mot recherché "musique"
#
# <img src="medias/plot-time-word.png" width="1700px">
#
# Exemple 2 : mot recherché "covid"
#
# <img src="medias/plot-time-word-2.png" width="1700px">
# <br>
# <br>
#
#
#
# #### La dernière statistique principale est celle qui décrit la variation du vocabulaire des artistes en montrant lesquels se répètent le plus dans leurs paroles. Pour cela, nous avons utilisé un histogramme en représentant le pourcentage de répétitions de mêmes mots par artistes.
#
# <img src="medias/plot-artist.png" width="1500px">
# <br>
# <br>

# %% [markdown]
# ### Donc le but général du projet est de présenter à l'aide de différentes statistiques l'utilisation la variété des mots utilisés dans les chansons de rap.

# %% [markdown]
# # 2. CORPS DU TRAVAIL

# %% [markdown]
# ## 2.1 Traitement et analyse de la liste des musiques avant récupération
# Ici le but est de traiter, nettoyer et analyser les données que l'on a en entrée pour notre analyse. Ces données représentent une liste de musiques avec leurs artistes (datas/songs.txt)

# %% [markdown]
# ### Paquets utilisés

# %%
import pandas as pd

# %% [markdown]
# ### Suppression des doublons
# Nous devons supprimer les éventuels doublons qui existent dans cette liste afin d'éviter de fausser nos résultats

# %%
songs: pd.Series

print("Suppression des doublons...", "\n\n")

with open("./datas/songs.txt", "r", encoding="utf8") as file:
    # Read the songs.txt file and create a pandas Serie from it
    songs_inputs = file.read().splitlines()
    songs = pd.Series(songs_inputs)

    print("Avant", "\n", songs, "\n", "...", "\n\n")
    
    # Remove duplicated songs (keep the first)
    songs.drop_duplicates(inplace=True)

    print("Après", "\n", songs, "\n", "...")

    # Rewrite the file without the duplicated values  
    with open("./datas/songs.txt", "w", encoding="utf8") as file:
        file.write("\n".join(songs))
        file.close()

    file.close()
# Out:
# Suppression des doublons...
#
#
# Avant
#  0                 Josman - F*cked Up 4
# 1                        Josman - Doré
# 2                   Josman - Décisions
# 3                         Josman - SEC
# 4       Josman - New Hares (Same Sh!t)
#                      ...
# 1825                    Di-Meh - Gâtée
# 1826                 Di-Meh - Week-end
# 1827                Di-Meh - Full Drip
# 1828                  Di-Meh - Daytona
# 1829         Di-Meh - 4x4 Diplomatique
# Length: 1830, dtype: object
#  ...
#
#
# Après
#  0                 Josman - F*cked Up 4
# 1                        Josman - Doré
# 2                   Josman - Décisions
# 3                         Josman - SEC
# 4       Josman - New Hares (Same Sh!t)
#                      ...
# 1825                    Di-Meh - Gâtée
# 1826                 Di-Meh - Week-end
# 1827                Di-Meh - Full Drip
# 1828                  Di-Meh - Daytona
# 1829         Di-Meh - 4x4 Diplomatique
# Length: 1830, dtype: object
#  ...

# %% [markdown]
# ### Représentation des artistes
# On va grouper les musiques par artistes, c'est-à-dire que pour chaque artiste nous faisons correspondre la liste de toutes ses musiques

# %%
# Split each lines using " - " (only the first occurence)
# "Green Montana - Follow-moi" => ["Green Montana", "Follow-moi"]
df_songs = songs.str.split(" - ", expand=True, n=1)
df_songs.columns = ["artist", "song"]

# Group the songs by artists
df_artists_songs = df_songs.groupby("artist")["song"].apply(list).reset_index(name="songs")
df_artists_songs["songs_count"] = df_artists_songs["songs"].apply(lambda x: len(x))
df_artists_songs.sort_values(by="songs_count", inplace=True, ascending=False)

df_artists_songs
# Out:
#          artist                                              songs  \
# 46          PNL  [DA, Naha, Dans la légende, Mira, J'suis QLF, ...
# 40       Nekfeu  [Les étoiles vagabondes, Alunissons, Cheum, Na...
# 51          SCH  [Gibraltar, Marché noir, Fournaise, Aluminium,...
# 10        Damso  [Ο. OG, Π. VANTABLACK, Ρ. DOSE, Σ. MOROSE, Τ. ...
# 35      Lomepal  [Palpal, 70, Lucy, Pommade, Ray Liotta, Ça com...
# ..          ...                                                ...
# 28   Kery James  [Si c'était à refaire, Parce que, Ce"A"d'avili...
# 22   Jazzy Bazz  [Crépuscule, El Presidente, Éternité, Leticia,...
# 30        Krisy  [Vol vers, Discussion nocturne, Blessed, Parad...
# 56        Swing  [N., Brousse, S'en aller, Pas besoin de raison...
# 39  Moji x Sboy    [Ma go, Regarde-moi, Pas comme elles, Medecine]
#
#     songs_count
# 46           70
# 40           68
# 51           67
# 10           58
# 35           56
# ..          ...
# 28           12
# 22           12
# 30            9
# 56            7
# 39            4
#
# [61 rows x 3 columns]

# %% [markdown]
# ### Histogramme des artistes depuis la liste (nettoyées) des musiques
# Nous pouvons maintenant afficher un histogramme depuis la liste (nettoyée) des musiques pour y voir plus clair, on affiche alors chacun de nos artistes avec son nombre de musiques que l'on possède

# %%
df_artists_songs.plot(
    kind="bar",
    x="artist",
    y="songs_count",
    figsize=(20, 10),
    label="Nombre de musiques",
    xlabel="Artiste"
)
# Out:
# <AxesSubplot:xlabel='Artiste'>

# %% [markdown]
# ## 2.2 Récupérations des informations des musiques
# Cette partie consiste à la récupération des données via l'API Genius, dans a partie précédente nous avons traité de la partie qui s'occupe des entrées de notre programme. Ici on va justement utiliser cette liste brute de musiques pour récupérer les paroles ainsi que notre information utilise relative à chacune des musiques.
# - Les informations liées à l'artiste
# - Les informations liées à l'album où la musique apparait
# - Les parole de la musique

# %% [markdown]
# ### Documentation
# La documentation de l'API Genius se trouve [ici](https://docs.genius.com/)

# %% [markdown]
# ## 2.3 Le scraping de données
# Malheureusement Genius ne fournit pas les paroles via son API, on doit alors ruser... La solution est la suivante:
# - On récupère l'URL de la page affichant les paroles via, car l'API nous le fournit
# - On fait une requête GET (HTTP) à cette adresse pour récupérer toute la page HTML affichant les paroles
# - Grâce au module BeautifulSoup on extrait uniquement le contenu de la balise HTML contenant les paroles de la musique

# %% [markdown]
# ### Paquets utilisés

# %%
import json
import requests
import time
import re
import pandas as pd
from datetime import datetime
from typing import List, Any
from rauth import OAuth2Service
from bs4 import BeautifulSoup, PageElement
from IPython.display import clear_output

# %% [markdown]
# ### Classe pour la manipulation de l'API
# Une classe nous simplifie grandement les appels à l'API Genius, nous avons alors fait une classe qui sert à:
# - Faire une recherche via l'API
# - Récupérer les informations spécifiques à une musique
# - Scraper les paroles de la musique

# %%
class API:
    """
    Simplify the requests to the Genius API
    """
    genius: Any
    session: Any

    def __init__(
        self,
        client_id: str,
        client_secret: str,
        authorize_url: str,
        base_url: str,
        token: str,
    ):
        """
        Initialize the Genius API session
        """
        self.genius = OAuth2Service(
            client_id=client_id,
            client_secret=client_secret,
            authorize_url=authorize_url,
            base_url=base_url
        )

        self.session = self.genius.get_session(
            token=token
        )

    def get_lyrics(
        self,
        url: str,
        retry: bool = False,
        wait_retry: int = 30,
        wait: int = 0
    ) -> dict:
        """
        Get the lyrics from the Genius website

        Parameters:
            url (str): The lyrics page URL
            retry (bool): Retry the request if it fails (default False)
            wait_retry (int): Wait x seconds before retrying (default 30)
            wait (int): Wait x seconds before returning the result (default 0)

        Returns:
            lyrics (str or None): The lyrics of the song
        """

        htmlRes = requests.get(url).text

        html = BeautifulSoup(htmlRes, "html.parser")

        # Find the correct lyrics div in the html file.
        # The classname could be "lyrics" or "Lyrics__Root-sc-1ynbvzw-0" 
        # Because the website stack probably use React or Angular with Server Side Rendering
        lyricsDiv: PageElement = html.find("div", class_="lyrics")
        if lyricsDiv == None:
            lyricsDiv = html.find("div", class_="Lyrics__Root-sc-1ynbvzw-0")

        if lyricsDiv != None:
            # We do not want <br>, so we simply replace each occurence with a line return (\n)
            # (could be replaced by a space, because we normalize it just after)
            for br in lyricsDiv.find_all("br"):
                br.replace_with("\n") 

            lyrics: str = lyricsDiv.get_text()

            # We normalize the lyrics by replacing each \n by a simple space (" ")
            # We do not want more than one space between each word so replace chained spaces by a single one ("a    b" => "a b")
            # And finally we remove spaces at the beginning 
            lyrics = re.sub(r"\n", " ", lyrics)
            lyrics = re.sub(r"\s{2,}", " ", lyrics)
            lyrics = lyrics.strip()

            # Optionnaly wait to avoid a ban from Genius's API
            time.sleep(wait)

            return lyrics

        elif retry:
            # Retry if it failed
            print(f"Cannot scrap lyrics... waiting {wait_retry} secondes")
            time.sleep(wait_retry)
            return self.get_lyrics(url, retry, wait_retry, wait)

        return None

    def get_song(
        self,
        id: int,
        with_lyrics: bool = False,
        retry: bool = False,
        wait_retry: int = 30,
        wait: int = 0
    ) -> dict:
        """
        Get a song from the Genius API and parse it into objects (selecting only interesting fields)

        Parameters:
            id (int): The song's ID
            with_lyrics (bool): Get the song with it's lyrics (default False)
            retry (bool): Retry the request if the getting lyrics method failed (default False)
            wait_retry (int): Wait x seconds if the getting lyrics method failed (default 30)
            wait (int): Wait x seconds after the lyrics method (default 0)

        Returns:
            lyrics (dict): The song
        """

        res = self.session.get(f"songs/{id}?text_format=plain").json()
        url = res['response']['song']['url']
        lyrics = ""

        album: dict = None

        # Extract only interesting informations about the song
        if res['response']['song']['album']:
            album = {
                "name": res['response']['song']['album']['name'],
                "id": res['response']['song']['album']['id']
            }            

        artist = {
            "name": res['response']['song']['primary_artist']['name'],
            "id": res['response']['song']['primary_artist']['id'],
            "url": res['response']['song']['primary_artist']['url'],
            "image": res['response']['song']['primary_artist']['image_url']
        }

        song = {
            "id": res['response']['song']['id'],
            "name": res['response']['song']['title'],
            "album": album,
            "artist": artist,
            "image": res['response']['song']['header_image_url'],
            "url": url,
            "original_lyrics": lyrics,
            "date": datetime.strptime(
                res['response']['song']['release_date'] or "1900-01-01", "%Y-%m-%d").isoformat()
        }

        if with_lyrics:
            lyrics = self.get_lyrics(url, retry, wait_retry, wait)

        if lyrics != None:
            song["original_lyrics"] = lyrics

        return song

    def search(self, query: str) -> List[dict]:
        """
        Search for an album, artist, song in the Genius API

        Parameters:
            query (str): The search query

        Returns:
            Results (List[dict]): The provided results
        """

        search = self.session.get(f"search?q={query}").json()
        hits = search['response']['hits']
        results: List[dict] = []

        for hit in hits:
        # Extract only interesting informations about the searched song
            hitResult = hit['result']

            artist = {
                "name": hitResult['primary_artist']['name'],
                "id": hitResult['primary_artist']['id'],
                "image": hitResult['primary_artist']['image_url'],
                "url": hitResult['primary_artist']['url']
            }

            search = {
                "title": hitResult['title'],
                "url": hitResult['url'],
                "artist": artist,
                "id": hitResult['id']
            }

            results.append(search)

        return results

    def print_json(content: str):
        print(json.dumps(content, indent=2, sort_keys=True))

# %% [markdown]
# ### Authentification à l'API
# Afin de faire des requêtes à l'API nous devons nous authentifier avec un token OAuth
# Ce token peut être généré à l'adresse suivante: [https://genius.com/api-clients](https://genius.com/api-clients)

# %%
# For the demo we let the tokens on purpose but we should avoid doing that
api = API(
    client_id="xAP0jvOkLrC3eAjwE4iCeY5BdSrgH7qKUQyh8907-2fGiAGYEHJMNhtFglSLznAq",
    client_secret="WIVq7t1Jq5uaN0OkYCPzhVMr4mt_d-ufoq5fSC6qmyUaxodx5kZ4bS56J87C-LXGRqeeXp9nFpjgrgPtZ_8niA",
    authorize_url="https://api.genius.com/oauth/authorize",
    base_url="https://api.genius.com/",
    token="qfhBonIalyiGK0DcsHmg3-heXf485c1dSV-gOM3ZU4Wn3eD-6-pKjESnhYg4kJ1y"
)

# %% [markdown]
# ### Récupération d'une musique avec l'API Genius

# %%
song = api.get_song(1)
API.print_json(song)
# Out:
# {
#   "album": {
#     "id": 360842,
#     "name": "Purple Haze (Advance)"
#   },
#   "artist": {
#     "id": 1,
#     "image": "https://images.genius.com/923801a14122014b9991a84a820f061c.420x420x1.png",
#     "name": "Cam\u2019ron",
#     "url": "https://genius.com/artists/Camron"
#   },
#   "date": "2004-12-07T00:00:00",
#   "id": 1,
#   "image": "https://images.rapgenius.com/bf520db552b4637bd9a8bbd072d9d290.316x314x1.jpg",
#   "name": "Killa Cam",
#   "original_lyrics": "",
#   "url": "https://genius.com/Camron-killa-cam-lyrics"
# }

# %% [markdown]
# ### Recherche d'une musique avec l'API Genius

# %%
results = api.search("damso")
API.print_json(results)
# Out:
# [
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3756041,
#     "title": "Feu de bois",
#     "url": "https://genius.com/Damso-feu-de-bois-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 2685480,
#     "title": "Amn\u00e9sie",
#     "url": "https://genius.com/Damso-amnesie-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3038927,
#     "title": "\u0393. Mosa\u00efque solitaire",
#     "url": "https://genius.com/Damso-mosaique-solitaire-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3041048,
#     "title": "\u0398. Macarena",
#     "url": "https://genius.com/Damso-macarena-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3042955,
#     "title": "N. J Respect R",
#     "url": "https://genius.com/Damso-n-j-respect-r-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3039687,
#     "title": "\u0395. Signaler",
#     "url": "https://genius.com/Damso-signaler-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 2462870,
#     "title": "Autotune",
#     "url": "https://genius.com/Damso-autotune-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3039913,
#     "title": "\u0396. Kietu",
#     "url": "https://genius.com/Damso-kietu-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3038921,
#     "title": "\u0391. Nwaar Is The New Black",
#     "url": "https://genius.com/Damso-nwaar-is-the-new-black-lyrics"
#   },
#   {
#     "artist": {
#       "id": 45855,
#       "image": "https://images.genius.com/57aa49f445bb856c82f4a8e6e5bffe55.1000x1000x1.jpg",
#       "name": "Damso",
#       "url": "https://genius.com/artists/Damso"
#     },
#     "id": 3673288,
#     "title": "Ips\u00e9it\u00e9",
#     "url": "https://genius.com/Damso-ipseite-lyrics"
#   }
# ]

# %% [markdown]
# ### Récupération des paroles d'une musique

# %%
lyrics = api.get_lyrics(song["url"])
lyrics
# Out:
# '[Chorus: Opera Steve & Cam\'ron] Killa Cam, Killa Cam, Cam Killa Cam, Killa Cam Killa Cam, Cam Killa Cam, Killa Cam, Cam Killa Killa Killa Cam Killa Cam, Cam, Killa (Killa!) Killa Cam, Killa Cam, Cam (Bases loaded) Killa Cam, Killa Cam (Uh-huh) Killa Cam, Cam (Santana on second, Jim on third) Killa Cam, Killa Cam, Cam (I\'m at bat) Killa Killa Killa Cam Killa Cam, Cam, Killa (I\'m \'bout to hit this shit out the world) Killa Cam (Ugh, Heatmakerz), Killa Cam, Cam Killa Cam, Killa Cam Killa Cam, Cam (Hahahaha) Killa Cam, Killa Cam, Cam Killa Killa Killa Cam Killa Cam, Cam, Killa (Clap) Killa Cam, Killa Cam, Cam Killa Cam, Killa Cam Killa Cam, Cam Killa Cam, Killa Cam, Cam Killa Killa Killa Cam (Killa! Killa!) Killa Cam, Cam, Killa [Verse 1] With the goons I spar, stay in tune with ma (What up?) She like, "Damn, this the realest since \'Kumbaya\'" Bomaye, Killa Cam, my Lord (My Lord) Still the man with the pan, scrilla, fam, on board Now bitches, they want to neuter me, niggas, they want to tutor me The hooligan in Houlihan\'s, maneuvering\'s nothing new to me Doggy, I\'m from the land of grind, pan-pan: gram or dime? Not toes or MC when I say "hammer time" Beef: I hammer mine, when I get my hands on nines If I had on \'Bama line, Corduroys, Cam\'ll shine Canary burgundy: I call it "Lemon Red" (Red) Yellow diamonds in my ear, call \'em "Lemonheads" Lemonhead, end up dead, ice like Winnipeg Gemstone, Flintstones, you could say I\'m friends with Fred You unhappy, scrappy? (What\'s going on, Scrappy?) I got Pataki at me Bitches say I\'m "Tacky Daddy," Range look like Laffy Taffy [Chorus] Killa Cam Killa Cam Cam (sing) Killa Cam Killa Cam Killa Cam Cam (uhh, it\'s me, clap) Killa Cam Killa Cam Cam Killa Killa Killa Cam (sing) Killa Cam Cam Killa (uhh, it\'s me, clap) Killa Cam Killa Cam Cam (sing) Killa Cam Killa Cam Killa Cam Cam (clap, it\'s me) Killa Cam Killa Cam Cam Killa Killa Killa Cam (clap) (Harlem, I know y\'all know about this) Killa Cam Cam Killa (Killa!) [Verse 2] Yo, I\'m from where Nicky Barnes got rich as fuck Rich and A hit the kitchens then were pitchin\' up Rob Base, Mase, Doug E Fresh switched it up I do both, who am I to fuck tradition up? (Killa!) So I parked in a tow-away zone Chrome...I don\'t care That car a throwaway, homes (Killa!) Welcome to Harlem, where you welcome to problems Off of furlough, fellow felons get pardons Them niggas knew we bang Stood out like Pootie Tang Soon as the stoolie sings That when the toolie sing! Bang! Bang! Came from that movie ring Snap, crack jewelry bling Flapjack, ooh he bring Clack-clack, "ooh he ring!" Bad rap, cuties cling Ass cap, put them in the river I\'m the sushi king And I\'ma keep ya fresh Let the fish eat ya flesh Yes sir, please confess Just say he\'s the best (Killa!) [Chorus] Killa Cam (sing) Killa Cam Cam (clap) Killa Cam Killa Cam (yes) Killa Cam Cam (it\'s me, sing) Killa Cam Killa Cam Cam (sing) Killa Killa Killa Cam Killa Cam Cam Killa (clap, yes sir, uhh) Killa Cam Killa Cam Cam (sing, clap) Killa Cam Killa Cam Killa Cam Cam (it\'s me) Killa Cam (sing, clap) Killa Cam Cam Killa Killa Killa Cam (Let me end this shit, listen) Killa Cam Cam Killa [Verse 3] (Killa!) Yo How dope is this? Teach you how to rope a chick What you want: coke or piff? Got it all, smoke or sniff? (everything) And you know my drift Used to figures, dough and shit (millions) You a rooster nigga, just a roaster, bitch And I roast ya bitch That\'s how it usually ends Tell her and her groupie friends Go get their coochie cleansed We the moody Gucci, Louis and Pucci men Escada, Prada The chopper it got the Uzi lens Bird\'s-eye view The birds I knew flip birds Bird gangs, it was birds I flew And word I blew off herb I grew I would serve on stoops Now swerve in coupes It\'s me, sing! Killa, uhh [Chorus] Killa Cam Killa Cam Cam Killa Cam Killa Cam Killa Cam Cam Killa Cam Killa Cam Cam Killa Killa Killa Cam Killa Cam Cam Killa Killa Cam Killa Cam Cam Killa Cam Killa Cam Killa Cam Cam Killa C ...

# %% [markdown]
# ## 2.4 Scraping des données
# Récupération de toutes les musiques d'un à partir du fichier contenant les musiques (datas/songs.txt)
# **Le code n'est pas exécuté (la fonction `scrap` n'est pas appelée, car commentée), cette opération peut durer plusieurs heures. Nous avons déjà effectué ce scraping afin de nourrir notre fichier songs.json, qui représente entre autres notre base de données des musiques**
#
# Comme nous l'avons déjà détaillé, les opérations suivantes pour chacune des musiques sont effectuées pour scraper les paroles
#
# - On utilise la méthode de recherche de la classe API (`api.search`)
#
# - Si des résultats sont donnés, on opère uniquement sur le premier résultat (qui est probablement celui qui nous intéresse) on récupéré les informations de ce résultat ("hit") qui représente la musique pas dans sa totalité, c'est la raison pour laquelle on fait cette opération  (`api.get_song`)
# Cette opération va également récupérer les paroles de la musique directement (grâce aux arguments passés à la méthode)
#
# - On ajoute cette musique dans une liste de résultats et on exporte cette liste en JSON dans le fichier `api_songs.json`
#
# > On exporte le fichier à chaque itération, car si la boucle est interrompue par une erreur on peut quand même récupérer la liste des musiques qui ont été récupérées

# %%
input_path: str = "./datas/songs.txt"
output_path: str = "./datas/api_songs.json"

def scrap():
    with open(input_path, "r", encoding="utf8") as file:
        songs_inputs = file.read().splitlines()
        songs: List[str] = []
      
        for index, song_input in enumerate(songs_inputs, start=1):
            # Search for a song with a query for example: "Green Montana - CALIFORNIA"
            results = api.search(song_input)

            # Retrieve all the songs informations and lyrics of the first result
            # (the first result is the one that we are interested in)
            if len(results) > 0:
                song = api.get_song(results[0]["id"], True, True, 0, 0)
                songs.append(song)

                print(f"{index / len(songs_inputs) * 100:.2f}%     {song['artist']['name']} - {song['name']}")
            
            # Write the file in JSON format at api_songs.json
            with open(output_path, "w", encoding="utf8") as output:
                output.write(
                    json.dumps(
                        songs,
                        default=lambda obj: obj.__dict__,
                        ensure_ascii=False
                    )
                )
                output.close()
        file.close()

    print("Le fichier JSON contenant les musiques a été écrit dans: ", output_path)

# We avoid calling this function because it can easily last few hours
# The result of our songs list is already in the file api_songs.json
# scrap()

# %% [markdown]
# ## 2.5 Clean des sons après récupération
# On ne peut pas se fier complètement à la recherche de l'API Genius, pour deux raisons:
#
# - Le son peut potentiellement ne pas exister dans la base de données de Genius
#
# - Le premier résultat n'est pas forcément le bon, on proposition d'amélioration aurait pu d'être de parcourir tous les résultats d'une recherche et vérifier si la musique recherchée n'apparait pas comme le deuxième, troisième ..., résultat
#
# Pour ces raisons nous allons filtrer que les musiques qui étaient bel et bien dans notre liste de musique au départ

# %% [markdown]
# ### Paquets utilisés

# %%
import json
import re
import pandas as pd
from typing import List

# %% [markdown]
# ### Application du tri
# En entrée on va prendre le fichier comportant la liste des musiques que l'on a scrapé auparavant (`api_songs.json`) et on va en premier temps vérifier, pour chacune des musiques, qu'elle existant au départ dans notre liste de sons brute (`songs.txt`) en recréant un champ `Artiste - Titre de musique` à partir des informations réelles de la musique. En deuxième temps, nous allons simplement supprimer tous les potentiels doublons qui pourraient apparaitre dans notre liste. Pour finalement afficher le pourcentage de musique que l'on peut exploiter.

# %%
input_path = "./datas/api_songs.json"
output_path = "./datas/songs.json"

songs = pd.read_json(input_path)
inputs: pd.Series

with open("./datas/songs.txt", "r", encoding="utf8") as file:
    inputs = pd.Series(file.read().lower().splitlines())
    file.close()

# We recreate the field "Artist - Title" in the DataFrame
songs["artist_name"] = songs['artist'].apply(pd.Series)["name"]
songs["query"] = songs['artist_name'].str.lower() + " - " + songs['name'].str.lower()

# We verify that the song exists in the file songs.txt
songs["is_in_inputs"] = songs["query"].isin(inputs)

# We filter the songs and remove the songs that aren't the the file songs.txt
songs = songs[songs["is_in_inputs"] == True]

# We remove the duplicated songs
songs.drop_duplicates(subset=["id"], inplace=True)

del songs["is_in_inputs"]
del songs["artist_name"]

print(f"Avec {len(inputs)} musiques, Genius a fourni {len(songs)} musiques de façon correcte")
print(f"Nous gardons alors {len(songs) / len(inputs) * 100:.2f}% de nos musiques pour la suite")

songs
# Out:
# Avec 1830 musiques, Genius a fourni 1268 musiques de façon correcte
# Nous gardons alors 69.29% de nos musiques pour la suite
#            id                   name                                  album  \
# 0     6408722            F*cked Up 4  {'name': 'MYSTR J.O.$', 'id': 726527}
# 1     6408724                   Doré  {'name': 'MYSTR J.O.$', 'id': 726527}
# 2     6408725              Décisions  {'name': 'MYSTR J.O.$', 'id': 726527}
# 3     6408726                    SEC  {'name': 'MYSTR J.O.$', 'id': 726527}
# 4     6408727  New Hares (Same Sh!t)  {'name': 'MYSTR J.O.$', 'id': 726527}
# ...       ...                    ...                                    ...
# 1813  6708599                 Follow      {'name': 'Mektoub', 'id': 760403}
# 1815  6708601                Turn Up      {'name': 'Mektoub', 'id': 760403}
# 1816  6708602                  Gâtée      {'name': 'Mektoub', 'id': 760403}
# 1817  6708603               Week-end      {'name': 'Mektoub', 'id': 760403}
# 1820  6679804       4x4 Diplomatique      {'name': 'Mektoub', 'id': 760403}
#
#                                                  artist  \
# 0     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 1     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 2     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 3     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 4     {'name': 'Josman', 'id': 153477, 'url': 'https...
# ...                                                 ...
# 1813  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1815  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1816  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1817  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1820  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
#
#                                                   image  \
# 0     https://images.genius.com/5d1737204d5b010efc28...
# 1     https://images.genius.com/b6488c411877313d186d...
# 2     https://images.genius.com/b6488c411877313d186d...
# 3     https://images.genius.com/b6488c411877313d186d...
# 4     https://images.genius.com/b6488c411877313d186d...
# ...                                                 ...
# 1813  https://images.genius.com/691df6a4289d4b326502...
# 1815  https://images.genius.com/691df6a4289d4b326502...
# 1816  https://images.genius.com/691df6a4289d4b326502...
# 1817  https://images.genius.com/691df6a4289d4b326502...
# 1820  https://images.genius.com/ea3d2df0059116a8acaa...
#
#                                                     url  \
# 0           https://genius.com/Josman-fcked-up-4-lyrics
# 1                 https://genius.com/Josman-dore-lyrics
# 2            https://genius.com/Josman-decisions-lyrics
# 3                  https://genius.com/Josman-sec-lyrics
# 4     https://genius.com/Josman-new-hares-same-sh-t-...
# ...                                                 ...
# 1813            https://genius.com/Di-meh-follow-lyrics
# 1815           https://genius.com/Di-meh-turn-up-lyrics
# 1816             https://genius.com/Di-meh-gatee-lyrics
# 1817          https://genius.com/Di-meh-week-end-lyrics
# 1820  https://genius.com/Di-meh-4x4-diplomatique-lyrics
#
#                                         original_lyrics                 date  \
# 0     [Paroles de "F*cked Up 4"] [Intro] J.O.S J.O.S...  2021-01-28T00:00:00
# 1     [Paroles de "Doré"] [Refrain] Le ciel est doré...  2021-01-29T00:00:00
# 2     [Paroles de "Décisions"] [Couplet 1] J'peux pa...  2021-01-29T00:00:00
# 3     [Paroles de "SEC"] [Intro] Sec comme le miel, ...  2021-01-29T00:00:00
# 4     [Paroles de "New Hares (Same Sh!t)"] [Couplet ...  2021-01-29T00:00:00
# ...                                                 ...                  ...
# 1813  [Paroles de "Follow"] [Refrain] Ouais j'y vais...  2021-05-14T00:00:00
# 1815  [Paroles de "Turn Up"] [Intro] Hmm Yeah Hmm [R...  2021-05-14T00:00:00
# 1816  [Paroles de "Gâtée"] [Refrain] Dis-moi pourquo...  2021-05-14T00:00:00
# 1817  [Paroles de "Week-end" ft. Klench Poko] RETRAN...  2021-05-14T00:00:00
# 1820  [Paroles de "4x4 Diplomatique"] [Intro] Di-Meh...  2021-04-08T00:00:00
#
#                                query
# 0               josman - f*cked up 4
# 1                      josman - doré
# 2                 josman - décisions
# 3                       josman - sec
# 4     josman - new hares (same sh!t)
# ...                              ...
# 1813                 di-meh - follow
# 1815                di-meh - turn up
# 1816                  di-meh - gâtée
# 1817               di-meh - week-end
# 1820       di-meh - 4x4 diplomatique
#
# [1268 rows x 9 columns]

# %% [markdown]
# ## 2.6 Créations de plusieurs champs dérivés des paroles originales
# Nous allons avoir besoin de plusieurs variations des paroles afin de procéder à nos statistiques.
# Notamment pour analyser grâce un dictionnaire de mots d'une langue les mots existant dans cette langue (`lyrics_keywords`)
#
# ### `original_lyrics`
# Les paroles originales, celles récupérées sur le site [genius.com](https://genius.com)
#
# ### `lyrics`
# Les paroles sans: `[Couplet]`, `mot94`, `34`, `  `
# - Supprime les accolades et leur contenu "\[...]"
# - Supprime toutes les parenthèses et leur contenu
# - Supprime tout ce qui n'est pas une lettre, une apostrophe ou un tirait (a-Z, ', -)
# - Supprime les lettres seules "abc d efg" => "abc efg"
# - Remplace plusieurs espaces par un seul "abc   def" => "abc def"
#
# ### `lyrics_keywords`
# Les paroles utilisées pour être comparées avec un dictionnaire, elles sont normalisées à leur forme la plus simple, effectue le même nettoyage que pour le champ `lyrics`, mais sans les mots basés sur des apostrophes, les apostrophes, les tiraient, etc.

# %%
# 1. Remove: "[...]"
# 2. Remove all the brackets and their contents "(...)"
# 3. Remove everything that is not a letter (a-Z) a word letter a single quote "'" or a "-"
# 4. Remove alone letters "abc d efg" => "abc efg"
# 5. Replace chained spaces by a single one "abc   def" => "abc def"
def clean_lyrics(lyrics: str):
    lyrics = re.sub(r"\([^()]*\)", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"\s*\[(.*?)\]\s*", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"[^a-zA-Z \w ' -]", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"\w*\d\w*", "", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"\s{2,}", " ", lyrics, flags=re.M | re.I)
    lyrics = lyrics.strip().lower()

    return lyrics

# Clean the lyrics like clean_lyrics does
# but it remove also the letters/words that can't be compared to a dictionnary
def clean_lyrics_keywords(lyrics: str):
    lyrics = clean_lyrics(lyrics)
    lyrics = re.sub(r"(^|\s)(qu'|j'|l'|t'|c'|t'|d'|s'|n'|y'|m')*", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"'(\s|$)", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"(\s|^)'", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"-(\s|$)", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"(\s|^)-", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"(^| ).(( ).)*( |$)", " ", lyrics, flags=re.M | re.I)
    lyrics = re.sub(r"\s{2,}", " ", lyrics, flags=re.M | re.I)
    lyrics = lyrics.strip().lower()

    return lyrics

songs["lyrics"] = songs["original_lyrics"].apply(clean_lyrics)
songs["lyrics_keywords"] = songs["original_lyrics"].apply(clean_lyrics_keywords)

songs_json = songs.to_json(force_ascii=False, orient="records")

with open(output_path, "w", encoding="utf8") as file:
    file.write(songs_json)
    file.close()

print("Le fichier JSON nettoyé a été écrit dans: ", output_path)
# Out:
# Le fichier JSON nettoyé a été écrit dans:  ./datas/songs.json

# %% [markdown]
# ## 2.7 Analyses des mots avec des dictionnaires de langue
# Nous passons à la partie des statistiques, on va afficher les mots créer dans le rap qui ne figure pas dans le dictionnaire français, ceci a pour but de faire ressortir les mots du verlan ainsi que les mots créer par ce genre musical (argots, créations, mot d'autres origines, etc.…). Nous allons également analyser les anglicismes les plus utilisés pour finir par afficher les mots français étant les plus employés.

# %% [markdown]
# ### Paquets utilisés
# On aura besoin des librairies externe:
# - [numpy](https://numpy.org/)
# - [pandas](https://pandas.pydata.org/)
# - [matplotlib](https://matplotlib.org/)
# - [wordcloud](https://amueller.github.io/word_cloud/)

# %%
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as ipw
from wordcloud import WordCloud
from typing import List

# %% [markdown]
# ### Ouverture des fichiers contenant les données à utiliser

# %%
songs: pd.DataFrame
french: pd.Series
english: pd.Series

songs = pd.read_json("./datas/songs.json")

with open("./datas/french.txt", "r", encoding="utf8") as file:
        french = pd.Series(file.read().lower().splitlines())
        file.close()

# Generated with http://app.aspell.net/create
with open("./datas/english.txt", "r", encoding="utf8") as file:
        english = pd.Series(file.read().lower().splitlines())
        file.close()

# %% [markdown]
# ### Sélection et manipulation des données afin de pouvoir les utiliser
# On va simplement comparer tous les mots que l'on possède avec le champ `lyrics_keywords`, compter leur nombre d'apparitions et filtrer cette liste de musiques en vérifiant que ces mots ne figurent pas dans le dictionnaire français et anglais, car on ne veut pas afficher les anglicismes ici

# %%
# Group all the words of all the songs in a single pd.Serie
words: pd.Series = songs["lyrics_keywords"].apply(lambda x: x.split(" ")).explode()

# Number of every differents words in all lyrics
all_words_count=len(words)

# Count all the words in this array
occurences: pd.Series = words.value_counts()

# Create a Dataframe that contains the number of occurence
# and if the word is inside the french dictionary
data = {
    "count": occurences,
    "is_french": occurences.index.isin(french),
    "is_english": occurences.index.isin(english)
}

description = pd.DataFrame(
    data=data,
    columns=["count", "is_french", "is_english"],
    index=occurences.index
)

#Select all the words and their count
words_count = pd.Series(description["count"], description.index)

# Select only the words that aren't french
not_french = description[description["is_french"] == False]
not_french = not_french[not_french["is_english"] == False]

frequency = pd.Series(not_french["count"], index=not_french.index)

with open("./datas/not_french.csv", "w", encoding="utf8") as f:
        f.write(frequency.to_csv())
        f.close()

not_french
# Out:
#            count  is_french  is_english
# p'tit        251      False       False
# biff         246      False       False
# wesh         164      False       False
# igo          138      False       False
# yah          131      False       False
# ...          ...        ...         ...
# p-diddy        1      False       False
# ye-yeah        1      False       False
# dioulasso      1      False       False
# qué-ni         1      False       False
# playeur        1      False       False
#
# [7252 rows x 3 columns]

# %% [markdown]
# Ceci est la liste des mots de figurant pas dans le dictionnaire français avec leurs occurrences (globale, parmi toutes les musiques)

# %% [markdown]
# # 3. STATISTIQUES SUR L'UTILISATION DES MOTS

# %% [markdown]
# ## 3.1 Recherche d'un mot particulier et pourcentage
# Pour jouer un peu avec la liste créée ci-dessus vous pouvez entrer un mot dans le champ ci-dessus afin de voir son nombre d'occurrences dans les paroles

# %%
# Textbox creation
word_textbox = ipw.Text(value="", placeholder="Search word", description="Word to count:", disabled=False)

# Function called when the button is clicked
def textbox_changed(word: str):
    word_searched = word.lower().strip()

    if word_searched in words_count:
        #number of times used
        print(f"Le mot \"{word_searched}\" est utilisé {words_count[word_searched]} fois dans toutes les paroles\n")
        #percentage of use
        percentage_used_word = round(words_count[word_searched] / all_words_count * 100, 2)
        print(f"Pourcentage d'utilisation: {percentage_used_word}%")
    else:
        print(f"Le mot \"{word_searched}\" ne se trouve pas dans les paroles")

# Button interaction
ipw.interact_manual(textbox_changed, word=word_textbox.value)
# Out:
# interactive(children=(Text(value='', description='word'), Button(description='Run Interact', style=ButtonStyle…
# <function __main__.textbox_changed(word: str)>

# %% [markdown]
# ## 3.2 Les mots ne figurant pas dans le dictionnaire français (ni anglais)
# ### L'argot, le verlan, etc.

# %% [markdown]
# ### WordCloud, plus le mot est grand, plus il est utilisé
# Voici une représentation des 50 mots en "word-cloud" les plus utilisés ne figurant pas dans le dictionnaire français
#
# Pour cette représentation on a utilisé le module [WordCloud](https://amueller.github.io/word_cloud/)

# %%
wordcloud = WordCloud(
    font_path="./medias/poppins.ttf",
    background_color="white",
    width=1600,
    height=800,
    max_words=50
).generate_from_frequencies(frequency.to_dict())

plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Histogramme des mots
# Une autre représentation possible de ces mots est en histogramme, voici alors les 30 mots les plus utilisés avec leurs nombres d'occurrences

# %%
frequency.head(30).plot(
    kind="bar",
    figsize=(14, 7),
    ylabel="Nombre d'utilisation",
    xlabel="Mot"
)
# Out:
# <AxesSubplot:xlabel='Mot', ylabel="Nombre d'utilisation">

# %% [markdown]
# ## 3.3 Les anglicismes
# On va analyser les mots les plus utilisés provenant de l'anglais

# %%
english_words = description[description["is_french"] == False]
english_words = english_words[english_words["is_english"] == True]

frequency = pd.Series(english_words["count"], index=english_words.index)

with open("./datas/english_words.csv", "w", encoding="utf8") as f:
        f.write(frequency.to_csv())
        f.close()

english_words
# Out:
#              count  is_french  is_english
# yeah          1556      False        True
# hey           1002      False        True
# fuck           428      False        True
# up             285      False        True
# the            268      False        True
# ...            ...        ...         ...
# society          1      False        True
# masterpiece      1      False        True
# sound            1      False        True
# hesitate         1      False        True
# etcetera         1      False        True
#
# [2236 rows x 3 columns]

# %% [markdown]
# ### WordCloud, plus le mot est grand, plus il est utilisé
# Voici une représentation des 50 mots en "word-cloud" les plus utilisés figurant dans le dictionnaire anglais
#
# Pour cette représentation on a utilisé le module [WordCloud](https://amueller.github.io/word_cloud/)

# %%
wordcloud = WordCloud(
    font_path="./medias/poppins.ttf",
    background_color="white",
    width=1600,
    height=800,
    max_words=50
).generate_from_frequencies(frequency.to_dict())

plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Histogramme des mots
# Une autre représentation possible de ces mots est en histogramme, voici alors les 30 mots les plus utilisés avec leurs nombres d'occurrences

# %%
frequency.head(30).plot(
    kind="bar",
    figsize=(14, 7),
    ylabel="Nombre d'utilisation",
    xlabel="Mot"
)
# Out:
# <AxesSubplot:xlabel='Mot', ylabel="Nombre d'utilisation">

# %% [markdown]
# ## 3.4 Le "vrai" français
# On va afficher les mots les plus utilisés figurant uniquement dans le dictionnaire français

# %%
french_words = description[description["is_french"] == True]

frequency = pd.Series(french_words["count"], index=french_words.index)

with open("./datas/french_words.csv", "w", encoding="utf8") as f:
        f.write(frequency.to_csv())
        f.close()

french_words
# Out:
#               count  is_french  is_english
# la            16560       True        True
# les           11280       True        True
# le            11012       True        True
# pas           11012       True        True
# de            10847       True        True
# ...             ...        ...         ...
# controverses      1       True       False
# roubignoles       1       True       False
# chauffait         1       True       False
# appartements      1       True        True
# étreinte          1       True       False
#
# [21901 rows x 3 columns]

# %% [markdown]
# ### WordCloud, plus le mot est grand, plus il est utilisé
# Voici une représentation en "word-cloud" des 50 mots les plus utilisés figurant dans le dictionnaire français
#
# Pour cette représentation on a utilisé le module [WordCloud](https://amueller.github.io/word_cloud/)

# %%
wordcloud = WordCloud(
    font_path="./medias/poppins.ttf",
    background_color="white",
    width=1600,
    height=800,
    max_words=50
).generate_from_frequencies(frequency.to_dict())

plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Histogramme
# Une autre représentation possible de ces mots est en histogramme, voici alors les 30 mots les plus utilisés avec leurs nombres d'occurrences

# %%
frequency.head(30).plot(
    kind="bar",
    figsize=(14, 7),
    ylabel="Nombre d'utilisation",
    xlabel="Mot"
)
# Out:
# <AxesSubplot:xlabel='Mot', ylabel="Nombre d'utilisation">

# %% [markdown]
# ## 3.5 Répartitions du langage
# Finalement, il est intéressant d'afficher grâce à un pie chart", la répartition de ces langues/langages

# %%
# Count number of words by language
french_words_count = len(description[description["is_french"] == True])
english_words_count = len(english_words)
other_words_count = len(not_french)

datas = [french_words_count, english_words_count, other_words_count]
labels = ["French", "English", "Other (slang)"]

plt.figure(figsize=(14, 7))
plt.title("Usage of language")

plt.pie(datas, labels=labels, autopct='% 1.1f%%')
plt.show()

# %% [markdown]
# # 4. STATISTIQUES SUR LES ARTISTES
# Pour le moment on n'a fait que des traitements sur les musiques sans prendre en compte l'artiste, ici on va justement traiter de ceux-ci.
#
# La difficulté est alors de "retourner la chaussette", c'est-à-dire de regrouper toutes les musiques par leur artiste ou lieu d'avoir une grande liste de musiques non groupée

# %% [markdown]
# ### Paquets utilisés

# %%
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as ipw
from wordcloud import WordCloud
from typing import List

# %% [markdown]
# ## 4.1 Regroupements des musiques par artistes
# Cette opération est plutôt fastidieuse, on va premièrement créer un champ contenant toutes les informations de l'artiste (dictionnaire) qui va nous permettre de grouper les musiques (par ce champ)

# %%
songs = pd.read_json("./datas/songs.json")

songs["lyrics_list"] = songs["lyrics"].apply(lambda x: x.split(" "))

artist_as_dataframe = songs['artist'].apply(pd.Series)
artist_as_dataframe.rename(columns=lambda x: "artist_" + str(x), inplace=True)

album_as_dataframe = songs['album'].apply(pd.Series)
album_as_dataframe.rename(columns=lambda x: "album_" + str(x), inplace=True)

songs = pd.concat([
    artist_as_dataframe,
    album_as_dataframe,
    songs
], axis=1)

songs["artist_dict"] = songs["artist"].apply(lambda x: json.dumps(x))

songs
# Out:
#      artist_name  artist_id                         artist_url  \
# 0         Josman     153477  https://genius.com/artists/Josman
# 1         Josman     153477  https://genius.com/artists/Josman
# 2         Josman     153477  https://genius.com/artists/Josman
# 3         Josman     153477  https://genius.com/artists/Josman
# 4         Josman     153477  https://genius.com/artists/Josman
# ...          ...        ...                                ...
# 1263      Di-Meh      60891  https://genius.com/artists/Di-meh
# 1264      Di-Meh      60891  https://genius.com/artists/Di-meh
# 1265      Di-Meh      60891  https://genius.com/artists/Di-meh
# 1266      Di-Meh      60891  https://genius.com/artists/Di-meh
# 1267      Di-Meh      60891  https://genius.com/artists/Di-meh
#
#                                            artist_image   album_name  \
# 0     https://images.genius.com/dffc429d8c62b65f4b92...  MYSTR J.O.$
# 1     https://images.genius.com/dffc429d8c62b65f4b92...  MYSTR J.O.$
# 2     https://images.genius.com/dffc429d8c62b65f4b92...  MYSTR J.O.$
# 3     https://images.genius.com/dffc429d8c62b65f4b92...  MYSTR J.O.$
# 4     https://images.genius.com/dffc429d8c62b65f4b92...  MYSTR J.O.$
# ...                                                 ...          ...
# 1263  https://images.genius.com/c618e1678656012159ad...      Mektoub
# 1264  https://images.genius.com/c618e1678656012159ad...      Mektoub
# 1265  https://images.genius.com/c618e1678656012159ad...      Mektoub
# 1266  https://images.genius.com/c618e1678656012159ad...      Mektoub
# 1267  https://images.genius.com/c618e1678656012159ad...      Mektoub
#
#       album_id       id                   name  \
# 0     726527.0  6408722            F*cked Up 4
# 1     726527.0  6408724                   Doré
# 2     726527.0  6408725              Décisions
# 3     726527.0  6408726                    SEC
# 4     726527.0  6408727  New Hares (Same Sh!t)
# ...        ...      ...                    ...
# 1263  760403.0  6708599                 Follow
# 1264  760403.0  6708601                Turn Up
# 1265  760403.0  6708602                  Gâtée
# 1266  760403.0  6708603               Week-end
# 1267  760403.0  6679804       4x4 Diplomatique
#
#                                       album  \
# 0     {'name': 'MYSTR J.O.$', 'id': 726527}
# 1     {'name': 'MYSTR J.O.$', 'id': 726527}
# 2     {'name': 'MYSTR J.O.$', 'id': 726527}
# 3     {'name': 'MYSTR J.O.$', 'id': 726527}
# 4     {'name': 'MYSTR J.O.$', 'id': 726527}
# ...                                     ...
# 1263      {'name': 'Mektoub', 'id': 760403}
# 1264      {'name': 'Mektoub', 'id': 760403}
# 1265      {'name': 'Mektoub', 'id': 760403}
# 1266      {'name': 'Mektoub', 'id': 760403}
# 1267      {'name': 'Mektoub', 'id': 760403}
#
#                                                  artist  \
# 0     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 1     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 2     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 3     {'name': 'Josman', 'id': 153477, 'url': 'https...
# 4     {'name': 'Josman', 'id': 153477, 'url': 'https...
# ...                                                 ...
# 1263  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1264  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1265  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1266  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
# 1267  {'name': 'Di-Meh', 'id': 60891, 'url': 'https:...
#
#                                                   image  \
# 0     https://images.genius.com/5d1737204d5b010efc28...
# 1     https://images.genius.com/b6488c411877313d186d...
# 2     https://images.genius.com/b6488c411877313d186d...
# 3     https://images.genius.com/b6488c411877313d186d...
# 4     https://images.genius.com/b6488c411877313d186d...
# ...                                                 ...
# 1263  https://images.genius.com/691df6a4289d4b326502...
# 1264  https://images.genius.com/691df6a4289d4b326502...
# 1265  https://images.genius.com/691df6a4289d4b326502...
# 1266  https://images.genius.com/691df6a4289d4b326502...
# 1267  https://images.genius.com/ea3d2df0059116a8acaa...
#
#                                                     url  \
# 0           https://genius.com/Josman-fcked-up-4-lyrics
# 1                 https://genius.com/Josman-dore-lyrics
# 2            https://genius.com/Josman-decisions-lyrics
# 3                  https://genius.com/Josman-sec-lyrics
# 4     https://genius.com/Josman-new-hares-same-sh-t-...
# ...                                                 ...
# 1263            https://genius.com/Di-meh-follow-lyrics
# 1264           https://genius.com/Di-meh-turn-up-lyrics
# 1265             https://genius.com/Di-meh-gatee-lyrics
# 1266          https://genius.com/Di-meh-week-end-lyrics
# 1267  https://genius.com/Di-meh-4x4-diplomatique-lyrics
#
#                                         original_lyrics                 date  \
# 0     [Paroles de "F*cked Up 4"] [Intro] J.O.S J.O.S...  2021-01-28T00:00:00
# 1     [Paroles de "Doré"] [Refrain] Le ciel est doré...  2021-01-29T00:00:00
# 2     [Paroles de "Décisions"] [Couplet 1] J'peux pa...  2021-01-29T00:00:00
# 3     [Paroles de "SEC"] [Intro] Sec comme le miel, ...  2021-01-29T00:00:00
# 4     [Paroles de "New Hares (Same Sh!t)"] [Couplet ...  2021-01-29T00:00:00
# ...                                                 ...                  ...
# 1263  [Paroles de "Follow"] [Refrain] Ouais j'y vais...  2021-05-14T00:00:00
# 1264  [Paroles de "Turn Up"] [Intro] Hmm Yeah Hmm [R...  2021-05-14T00:00:00
# 1265  [Paroles de "Gâtée"] [Refrain] Dis-moi pourquo...  2021-05-14T00:00:00
# 1266  [Paroles de "Week-end" ft. Klench Poko] RETRAN...  2021-05-14T00:00:00
# 1267  [Paroles de "4x4 Diplomatique"] [Intro] Di-Meh...  2021-04-08T00:00:00
#
#                                query  \
# 0               josman - f*cked up 4
# 1                      josman - doré
# 2                 josman - décisions
# 3                       josman - sec
# 4     josman - new hares (same sh!t)
# ...                              ...
# 1263                 di-meh - follow
# 1264                di-meh - turn up
# 1265                  di-meh - gâtée
# 1266               di-meh - week-end
# 1267       di-meh - 4x4 diplomatique
#
#                                                  lyrics  \
# 0     j o s j o s j o s j o s j o s j o s j o s j o ...
# 1     le ciel est doré j'allume mon doré j'sais pas ...
# 2     j'peux pas m'afficher j'peux pas paraître ridi...
# 3     sec comme le miel yah tu m'verras pas ému même...
# 4     vrai négro gros nez épaté j'lâche des phases i...
# ...                                                 ...
# 1263  ouais j'y vais solo qui m'aime me follow qui m...
# 1264  hmm yeah hmm pour qu'on turn up turn up turn u...
# 1265  dis-moi pourquoi t'as tout gâtée t'aimes bien ...
# 1266      retranscription en cours ne pas toucher merci
# 1267  di-meh ah ah j'fume un gros teh sur le port de...
#
#                                         lyrics_keywords  \
# 0     monnaie sur té-c té-c bois le jack sec sec rou...
# 1     le ciel est doré allume mon doré sais pas sur ...
# 2     peux pas afficher peux pas paraître ridicule r...
# 3     sec comme le miel yah tu verras pas ému même s...
# 4     vrai négro gros nez épaté lâche des phases ils...
# ...                                                 ...
# 1263  ouais vais solo qui aime me follow qui aime me...
# 1264  hmm yeah hmm pour on turn up turn up turn up t...
# 1265  dis-moi pourquoi as tout gâtée aimes bien ment...
# 1266      retranscription en cours ne pas toucher merci
# 1267  di-meh ah ah fume un gros teh sur le port de r...
#
#                                             lyrics_list  \
# 0     [j, o, s, j, o, s, j, o, s, j, o, s, j, o, s, ...
# 1     [le, ciel, est, doré, j'allume, mon, doré, j's...
# 2     [j'peux, pas, m'afficher, j'peux, pas, paraîtr...
# 3     [sec, comme, le, miel, yah, tu, m'verras, pas,...
# 4     [vrai, négro, gros, nez, épaté, j'lâche, des, ...
# ...                                                 ...
# 1263  [ouais, j'y, vais, solo, qui, m'aime, me, foll...
# 1264  [hmm, yeah, hmm, pour, qu'on, turn, up, turn, ...
# 1265  [dis-moi, pourquoi, t'as, tout, gâtée, t'aimes...
# 1266  [retranscription, en, cours, ne, pas, toucher,...
# 1267  [di-meh, ah, ah, j'fume, un, gros, teh, sur, l...
#
#                                             artist_dict
# 0     {"name": "Josman", "id": 153477, "url": "https...
# 1     {"name": "Josman", "id": 153477, "url": "https...
# 2     {"name": "Josman", "id": 153477, "url": "https...
# 3     {"name": "Josman", "id": 153477, "url": "https...
# 4     {"name": "Josman", "id": 153477, "url": "https...
# ...                                                 ...
# 1263  {"name": "Di-Meh", "id": 60891, "url": "https:...
# 1264  {"name": "Di-Meh", "id": 60891, "url": "https:...
# 1265  {"name": "Di-Meh", "id": 60891, "url": "https:...
# 1266  {"name": "Di-Meh", "id": 60891, "url": "https:...
# 1267  {"name": "Di-Meh", "id": 60891, "url": "https:...
#
# [1268 rows x 19 columns]

# %%
artists_songs = pd.DataFrame(songs.groupby("artist_dict").apply(lambda g: g.to_dict("records"))).reset_index()

artists_songs.columns = ["artist", "songs"]

artists_songs["artist"] = artists_songs["artist"].apply(lambda x: json.loads(x))

artists = pd.DataFrame.from_dict(artists_songs["artist"].to_dict(), orient="index")

artists["songs"] = artists_songs["songs"]
artists["songs_count"] = artists_songs["songs"].map(lambda x: len(x))

artists = artists.sort_values("songs_count", ascending=False)

artists["artist_id"] = artists["name"].str.lower()
artists.set_index("artist_id", inplace=True)

artists
# Out:
#                                       name       id  \
# artist_id
# pnl                                    PNL   335710
# sch                                    SCH   276476
# nekfeu                              Nekfeu    13063
# damso                                Damso    45855
# jul                                    JuL    74283
# lomepal                            Lomepal    16138
# orelsan                            OrelSan     1286
# booba                                Booba     1282
# hatik                                Hatik   147321
# hamza                                Hamza    74111
# s.pri noir                      S.Pri Noir    15330
# disiz la peste              Disiz La Peste     2252
# niska                                Niska   234413
# vald                                  Vald    19217
# dinos                                Dinos    14806
# zed yun pavarotti        Zed Yun Pavarotti  1276822
# kaaris                              Kaaris    14693
# deen burbigo                  Deen Burbigo    14071
# laylow                              Laylow   308564
# roméo elvis                    Roméo Elvis    75161
# makala                              Makala    94448
# lefa                                  Lefa    15927
# plk                                    PLK   128813
# népal                                Népal    19547
# sneazzy                            Sneazzy    13508
# sopico                              Sopico   235193
# georgio                            Georgio    21841
# oboy                                  OBOY   635729
# bosh                                  Bosh   314635
# 1995                                  1995    12091
# 13 block                          13 Block   327072
# zola                                  Zola  1101709
# la fouine                        La Fouine     1303
# josman                              Josman   153477
# kalash criminel            Kalash Criminel   592670
# alpha wann                      Alpha Wann    13062
# luidji                              Luidji    14723
# freeze corleone            Freeze Corleone    63888
# 7 jaws                              7 Jaws  1078135
# youv dee                          Youv Dee   933047
# bu$hi                                BU$HI  1233575
# rohff                                Rohff     1908
# koba lad                          Koba LaD  1247832
# jazzy bazz                      Jazzy Bazz    13956
# green montana                Green Montana  1650901
# di-meh                              Di-Meh    60891
# columbine                        Columbine   315143
# gazo                                  Gazo    23012
# lunatic                            Lunatic     1945
# suprême ntm                    Suprême NTM    24568
# krisy                                Krisy    21255
# kery james                      Kery James     1273
# swing                                Swing     8444
# moji x sboy                    Moji x Sboy  1817377
# caballero & jeanjass  Caballero & JeanJass   639298
#
#                                                                     url  \
# artist_id
# pnl                                      https://genius.com/artists/Pnl
# sch                                      https://genius.com/artists/Sch
# nekfeu                                https://genius.com/artists/Nekfeu
# damso                                  https://genius.com/artists/Damso
# jul                                      https://genius.com/artists/Jul
# lomepal                              https://genius.com/artists/Lomepal
# orelsan                              https://genius.com/artists/Orelsan
# booba                                  https://genius.com/artists/Booba
# hatik                                  https://genius.com/artists/Hatik
# hamza                                  https://genius.com/artists/Hamza
# s.pri noir                         https://genius.com/artists/Spri-noir
# disiz la peste                https://genius.com/artists/Disiz-la-peste
# niska                                  https://genius.com/artists/Niska
# vald                                    https://genius.com/artists/Vald
# dinos                                  https://genius.com/artists/Dinos
# zed yun pavarotti          https://genius.com/artists/Zed-yun-pavarotti
# kaaris                                https://genius.com/artists/Kaaris
# deen burbigo                    https://genius.com/artists/Deen-burbigo
# laylow                                https://genius.com/artists/Laylow
# roméo elvis                      https://genius.com/artists/Romeo-elvis
# makala                                https://genius.com/artists/Makala
# lefa                                    https://genius.com/artists/Lefa
# plk                                      https://genius.com/artists/Plk
# népal                                  https://genius.com/artists/Nepal
# sneazzy                              https://genius.com/artists/Sneazzy
# sopico                                https://genius.com/artists/Sopico
# georgio                              https://genius.com/artists/Georgio
# oboy                                    https://genius.com/artists/Oboy
# bosh                                    https://genius.com/artists/Bosh
# 1995                                    https://genius.com/artists/1995
# 13 block                            https://genius.com/artists/13-block
# zola                                    https://genius.com/artists/Zola
# la fouine                          https://genius.com/artists/La-fouine
# josman                                https://genius.com/artists/Josman
# kalash criminel              https://genius.com/artists/Kalash-criminel
# alpha wann                        https://genius.com/artists/Alpha-wann
# luidji                                https://genius.com/artists/Luidji
# freeze corleone              https://genius.com/artists/Freeze-corleone
# 7 jaws                                https://genius.com/artists/7-jaws
# youv dee                            https://genius.com/artists/Youv-dee
# bu$hi                                  https://genius.com/artists/Bu-hi
# rohff                                  https://genius.com/artists/Rohff
# koba lad                            https://genius.com/artists/Koba-lad
# jazzy bazz                        https://genius.com/artists/Jazzy-bazz
# green montana                  https://genius.com/artists/Green-montana
# di-meh                                https://genius.com/artists/Di-meh
# columbine                          https://genius.com/artists/Columbine
# gazo                                    https://genius.com/artists/Gazo
# lunatic                              https://genius.com/artists/Lunatic
# suprême ntm                      https://genius.com/artists/Supreme-ntm
# krisy                                  https://genius.com/artists/Krisy
# kery james                        https://genius.com/artists/Kery-james
# swing                                  https://genius.com/artists/Swing
# moji x sboy                      https://genius.com/artists/Moji-x-sboy
# caballero & jeanjass  https://genius.com/artists/Caballero-and-jeanjass
#
#                                                                   image  \
# artist_id
# pnl                   https://images.genius.com/1518f8e82d8a48060c5e...
# sch                   https://images.genius.com/dfa1dc4028ae9d7567cd...
# nekfeu                https://images.genius.com/5f89988a816404d2f29a...
# damso                 https://images.genius.com/57aa49f445bb856c82f4...
# jul                   https://images.genius.com/3d6d65909c61ae6035e8...
# lomepal               https://images.genius.com/cf19fa33f7a1cd3b1dd9...
# orelsan               https://images.genius.com/e31f6adc3dec9edafab8...
# booba                 https://images.genius.com/f87d62132f88bf91eee1...
# hatik                 https://images.genius.com/4d36213b4fdb8ef9a77b...
# hamza                 https://images.genius.com/4e999f4c4332ed7339dc...
# s.pri noir            https://images.genius.com/452fb5bb6afafde98160...
# disiz la peste        https://images.genius.com/f5c4d9d28be4cae13e5e...
# niska                 https://images.genius.com/7b9ad14cd4defcf386ac...
# vald                  https://images.genius.com/39c8b2b31afea4a29bc8...
# dinos                 https://images.genius.com/591d089a09ca3b4906bb...
# zed yun pavarotti     https://images.genius.com/ab65b042d11f12a286d3...
# kaaris                https://images.genius.com/5c49c23c8e408fb8d863...
# deen burbigo          https://images.genius.com/3b7a67109388e7135422...
# laylow                https://images.genius.com/d9e11a197886a8795629...
# roméo elvis           https://images.genius.com/bf383cc49f0c3824d72e...
# makala                https://images.genius.com/3ac42be4fbca819d018c...
# lefa                  https://images.genius.com/c20c661812494d9b3f7c...
# plk                   https://images.genius.com/c09cce477e2697170eb1...
# népal                 https://images.genius.com/4a06b9304948c1278d57...
# sneazzy               https://images.genius.com/f89e15af72c458c417a6...
# sopico                https://images.genius.com/42014f3e25894c4f638b...
# georgio               https://images.genius.com/b7fa89dd7c4e042cfbf5...
# oboy                  https://images.genius.com/252dcb722d9851a5ee8d...
# bosh                  https://images.genius.com/a9e8d1f32b8e06ad760b...
# 1995                  https://images.genius.com/0d0c589a33ca5244d534...
# 13 block              https://images.genius.com/475cbda85c9a0cf007d0...
# zola                  https://images.genius.com/8aef51aedcdfadd5eef6...
# la fouine             https://images.genius.com/85a9f2fff1af7fbc1991...
# josman                https://images.genius.com/dffc429d8c62b65f4b92...
# kalash criminel       https://images.genius.com/3ec9bdee9486fdf90ad7...
# alpha wann            https://images.genius.com/9eceb53405edce9e2226...
# luidji                https://images.genius.com/a8a0e2ed1cb27d7742f2...
# freeze corleone       https://images.genius.com/3363b0155abaa3b46e95...
# 7 jaws                https://images.genius.com/53228993bf27577b8a39...
# youv dee              https://images.genius.com/1bb69d02b029f3ffb74a...
# bu$hi                 https://images.genius.com/050576e9808baedd8ef1...
# rohff                 https://images.genius.com/e7d85b983e15fcf9b3af...
# koba lad              https://images.genius.com/bf0af9e36f2dd292b14c...
# jazzy bazz            https://images.genius.com/1404d03558b5bab5530a...
# green montana         https://images.genius.com/b1a4449b1281a51c22da...
# di-meh                https://images.genius.com/c618e1678656012159ad...
# columbine             https://images.genius.com/1fe7daf087e6825cef60...
# gazo                  https://images.genius.com/f9c286115fac81dcac5d...
# lunatic               https://images.genius.com/988880b2a371c8ede99a...
# suprême ntm           https://images.genius.com/949ffbea5ebe16dd1762...
# krisy                 https://images.genius.com/6400f38376f2ec97d525...
# kery james            https://images.genius.com/74cf66f613495ab9c902...
# swing                 https://images.genius.com/b7403990aa1d693cfd2d...
# moji x sboy           https://images.genius.com/6d8e5c686e7c3224514c...
# caballero & jeanjass  https://images.genius.com/162dab2faa69d8a7035a...
#
#                                                                   songs  \
# artist_id
# pnl                   [{'artist_name': 'PNL', 'artist_id': 335710, '...
# sch                   [{'artist_name': 'SCH', 'artist_id': 276476, '...
# nekfeu                [{'artist_name': 'Nekfeu', 'artist_id': 13063,...
# damso                 [{'artist_name': 'Damso', 'artist_id': 45855, ...
# jul                   [{'artist_name': 'JuL', 'artist_id': 74283, 'a...
# lomepal               [{'artist_name': 'Lomepal', 'artist_id': 16138...
# orelsan               [{'artist_name': 'OrelSan', 'artist_id': 1286,...
# booba                 [{'artist_name': 'Booba', 'artist_id': 1282, '...
# hatik                 [{'artist_name': 'Hatik', 'artist_id': 147321,...
# hamza                 [{'artist_name': 'Hamza', 'artist_id': 74111, ...
# s.pri noir            [{'artist_name': 'S.Pri Noir', 'artist_id': 15...
# disiz la peste        [{'artist_name': 'Disiz La Peste', 'artist_id'...
# niska                 [{'artist_name': 'Niska', 'artist_id': 234413,...
# vald                  [{'artist_name': 'Vald', 'artist_id': 19217, '...
# dinos                 [{'artist_name': 'Dinos', 'artist_id': 14806, ...
# zed yun pavarotti     [{'artist_name': 'Zed Yun Pavarotti', 'artist_...
# kaaris                [{'artist_name': 'Kaaris', 'artist_id': 14693,...
# deen burbigo          [{'artist_name': 'Deen Burbigo', 'artist_id': ...
# laylow                [{'artist_name': 'Laylow', 'artist_id': 308564...
# roméo elvis           [{'artist_name': 'Roméo Elvis', 'artist_id': 7...
# makala                [{'artist_name': 'Makala', 'artist_id': 94448,...
# lefa                  [{'artist_name': 'Lefa', 'artist_id': 15927, '...
# plk                   [{'artist_name': 'PLK', 'artist_id': 128813, '...
# népal                 [{'artist_name': 'Népal', 'artist_id': 19547, ...
# sneazzy               [{'artist_name': 'Sneazzy', 'artist_id': 13508...
# sopico                [{'artist_name': 'Sopico', 'artist_id': 235193...
# georgio               [{'artist_name': 'Georgio', 'artist_id': 21841...
# oboy                  [{'artist_name': 'OBOY', 'artist_id': 635729, ...
# bosh                  [{'artist_name': 'Bosh', 'artist_id': 314635, ...
# 1995                  [{'artist_name': '1995', 'artist_id': 12091, '...
# 13 block              [{'artist_name': '13 Block', 'artist_id': 3270...
# zola                  [{'artist_name': 'Zola', 'artist_id': 1101709,...
# la fouine             [{'artist_name': 'La Fouine', 'artist_id': 130...
# josman                [{'artist_name': 'Josman', 'artist_id': 153477...
# kalash criminel       [{'artist_name': 'Kalash Criminel', 'artist_id...
# alpha wann            [{'artist_name': 'Alpha Wann', 'artist_id': 13...
# luidji                [{'artist_name': 'Luidji', 'artist_id': 14723,...
# freeze corleone       [{'artist_name': 'Freeze Corleone', 'artist_id...
# 7 jaws                [{'artist_name': '7 Jaws', 'artist_id': 107813...
# youv dee              [{'artist_name': 'Youv Dee', 'artist_id': 9330...
# bu$hi                 [{'artist_name': 'BU$HI', 'artist_id': 1233575...
# rohff                 [{'artist_name': 'Rohff', 'artist_id': 1908, '...
# koba lad              [{'artist_name': 'Koba LaD', 'artist_id': 1247...
# jazzy bazz            [{'artist_name': 'Jazzy Bazz', 'artist_id': 13...
# green montana         [{'artist_name': 'Green Montana', 'artist_id':...
# di-meh                [{'artist_name': 'Di-Meh', 'artist_id': 60891,...
# columbine             [{'artist_name': 'Columbine', 'artist_id': 315...
# gazo                  [{'artist_name': 'Gazo', 'artist_id': 23012, '...
# lunatic               [{'artist_name': 'Lunatic', 'artist_id': 1945,...
# suprême ntm           [{'artist_name': 'Suprême NTM', 'artist_id': 2...
# krisy                 [{'artist_name': 'Krisy', 'artist_id': 21255, ...
# kery james            [{'artist_name': 'Kery James', 'artist_id': 12...
# swing                 [{'artist_name': 'Swing', 'artist_id': 8444, '...
# moji x sboy           [{'artist_name': 'Moji x Sboy', 'artist_id': 1...
# caballero & jeanjass  [{'artist_name': 'Caballero & JeanJass', 'arti...
#
#                       songs_count
# artist_id
# pnl                            57
# sch                            54
# nekfeu                         52
# damso                          50
# jul                            41
# lomepal                        40
# orelsan                        40
# booba                          39
# hatik                          38
# hamza                          36
# s.pri noir                     35
# disiz la peste                 35
# niska                          33
# vald                           32
# dinos                          31
# zed yun pavarotti              29
# kaaris                         28
# deen burbigo                   28
# laylow                         27
# roméo elvis                    27
# makala                         25
# lefa                           25
# plk                            25
# népal                          24
# sneazzy                        23
# sopico                         23
# georgio                        22
# oboy                           21
# bosh                           21
# 1995                           20
# 13 block                       20
# zola                           18
# la fouine                      18
# josman                         18
# kalash criminel                17
# alpha wann                     16
# luidji                         15
# freeze corleone                15
# 7 jaws                         13
# youv dee                       13
# bu$hi                          13
# rohff                          13
# koba lad                       13
# jazzy bazz                     12
# green montana                  10
# di-meh                         10
# columbine                       9
# gazo                            8
# lunatic                         7
# suprême ntm                     7
# krisy                           7
# kery james                      6
# swing                           5
# moji x sboy                     3
# caballero & jeanjass            1

# %% [markdown]
# On obtient ici la liste de tous les artistes avec un champ contenant la liste de ses musiques sous forme de dictionnaire

# %% [markdown]
# ## 4.2 Représentations des pertes dues au nettoyage des musiques au niveau des artistes
# Grâce à ce groupement par artiste on va pouvoir représenter graphiquement les pertes engendrées par le nettoyage du fichier `api_songs.json`
#
# La barre bleue montre le nombre de musiques que l'on voulait récupérer de base, en orange c'est ce que l'on a pu obtenir après le nettoyage des données

# %%
songs_inputs: pd.Series

with open("./datas/songs.txt", "r", encoding="utf8") as file:
    songs_inputs = pd.Series(file.read().splitlines())
    file.close()

songs = songs_inputs.str.split(" - ", expand=True, n=1)
songs.columns = ["artist", "song"]

# Group the songs by artists
artists_comparaison = songs.groupby("artist")["song"].apply(list).reset_index(name="songs")
artists_comparaison["songs_count"] = artists_comparaison["songs"].apply(lambda x: len(x))
artists_comparaison.sort_values(by="songs_count", inplace=True, ascending=False)

artists_comparaison["artist_id"] = artists_comparaison["artist"].str.lower()
artists_comparaison.set_index("artist_id", inplace=True)

artists_comparaison["songs_count_after_clean"] = artists["songs_count"]
artists_comparaison = artists_comparaison[["artist", "songs_count", "songs_count_after_clean"]]

# Display the histogram
artists_comparaison.columns = ["Artiste", "Nombre de musiques initial", "Nombre de musiques après filtre"]
artists_comparaison.plot.bar(
    x="Artiste",
    figsize=(25, 10)
)
# Out:
# <AxesSubplot:xlabel='Artiste'>

# %% [markdown]
# ## 4.3 Calculs du pourcentage de répétition
# Une statistique plutôt intéressante est de mesurer la richesse du vocabulaire des artistes en montrant lesquels se répètent le plus dans leurs paroles via un histogramme

# %%
def select_words(song: dict):
    songs_count = len(song)

    song_df = pd.DataFrame(song)
    words = song_df["lyrics"].map(lambda x: x.split(" ")).explode().to_list()

    return words

def select_unique_words(words: list):
    return pd.Series(words).drop_duplicates().to_list()

# All the used words of the artist
artists["words"] = artists["songs"].map(select_words)
artists["words_count"] = artists["words"].map(lambda x: len(x))

# All the used words os the artist but without duplications
artists["unique_words"] = artists["words"].map(select_unique_words)
artists["unique_words_count"] = artists["unique_words"].map(lambda x: len(x))

# Count the number of repetition
artists["reptition_count"] = artists["words_count"] - artists["unique_words_count"]

# Make a percentage of the repetitions
artists["repetition_percentage"] = artists["reptition_count"] / artists["words_count"] * 100

artists.sort_values(by="repetition_percentage", inplace=True)

artists
# Out:
#                                       name       id  \
# artist_id
# columbine                        Columbine   315143
# rohff                                Rohff     1908
# lunatic                            Lunatic     1945
# jazzy bazz                      Jazzy Bazz    13956
# suprême ntm                    Suprême NTM    24568
# swing                                Swing     8444
# kery james                      Kery James     1273
# caballero & jeanjass  Caballero & JeanJass   639298
# 1995                                  1995    12091
# luidji                              Luidji    14723
# moji x sboy                    Moji x Sboy  1817377
# alpha wann                      Alpha Wann    13062
# zola                                  Zola  1101709
# bu$hi                                BU$HI  1233575
# népal                                Népal    19547
# green montana                Green Montana  1650901
# di-meh                              Di-Meh    60891
# freeze corleone            Freeze Corleone    63888
# lefa                                  Lefa    15927
# booba                                Booba     1282
# krisy                                Krisy    21255
# laylow                              Laylow   308564
# kaaris                              Kaaris    14693
# makala                              Makala    94448
# vald                                  Vald    19217
# koba lad                          Koba LaD  1247832
# deen burbigo                  Deen Burbigo    14071
# 7 jaws                              7 Jaws  1078135
# 13 block                          13 Block   327072
# sopico                              Sopico   235193
# la fouine                        La Fouine     1303
# georgio                            Georgio    21841
# sneazzy                            Sneazzy    13508
# josman                              Josman   153477
# youv dee                          Youv Dee   933047
# kalash criminel            Kalash Criminel   592670
# disiz la peste              Disiz La Peste     2252
# bosh                                  Bosh   314635
# gazo                                  Gazo    23012
# orelsan                            OrelSan     1286
# s.pri noir                      S.Pri Noir    15330
# plk                                    PLK   128813
# damso                                Damso    45855
# dinos                                Dinos    14806
# nekfeu                              Nekfeu    13063
# oboy                                  OBOY   635729
# lomepal                            Lomepal    16138
# sch                                    SCH   276476
# roméo elvis                    Roméo Elvis    75161
# niska                                Niska   234413
# hatik                                Hatik   147321
# zed yun pavarotti        Zed Yun Pavarotti  1276822
# pnl                                    PNL   335710
# jul                                    JuL    74283
# hamza                                Hamza    74111
#
#                                                                     url  \
# artist_id
# columbine                          https://genius.com/artists/Columbine
# rohff                                  https://genius.com/artists/Rohff
# lunatic                              https://genius.com/artists/Lunatic
# jazzy bazz                        https://genius.com/artists/Jazzy-bazz
# suprême ntm                      https://genius.com/artists/Supreme-ntm
# swing                                  https://genius.com/artists/Swing
# kery james                        https://genius.com/artists/Kery-james
# caballero & jeanjass  https://genius.com/artists/Caballero-and-jeanjass
# 1995                                    https://genius.com/artists/1995
# luidji                                https://genius.com/artists/Luidji
# moji x sboy                      https://genius.com/artists/Moji-x-sboy
# alpha wann                        https://genius.com/artists/Alpha-wann
# zola                                    https://genius.com/artists/Zola
# bu$hi                                  https://genius.com/artists/Bu-hi
# népal                                  https://genius.com/artists/Nepal
# green montana                  https://genius.com/artists/Green-montana
# di-meh                                https://genius.com/artists/Di-meh
# freeze corleone              https://genius.com/artists/Freeze-corleone
# lefa                                    https://genius.com/artists/Lefa
# booba                                  https://genius.com/artists/Booba
# krisy                                  https://genius.com/artists/Krisy
# laylow                                https://genius.com/artists/Laylow
# kaaris                                https://genius.com/artists/Kaaris
# makala                                https://genius.com/artists/Makala
# vald                                    https://genius.com/artists/Vald
# koba lad                            https://genius.com/artists/Koba-lad
# deen burbigo                    https://genius.com/artists/Deen-burbigo
# 7 jaws                                https://genius.com/artists/7-jaws
# 13 block                            https://genius.com/artists/13-block
# sopico                                https://genius.com/artists/Sopico
# la fouine                          https://genius.com/artists/La-fouine
# georgio                              https://genius.com/artists/Georgio
# sneazzy                              https://genius.com/artists/Sneazzy
# josman                                https://genius.com/artists/Josman
# youv dee                            https://genius.com/artists/Youv-dee
# kalash criminel              https://genius.com/artists/Kalash-criminel
# disiz la peste                https://genius.com/artists/Disiz-la-peste
# bosh                                    https://genius.com/artists/Bosh
# gazo                                    https://genius.com/artists/Gazo
# orelsan                              https://genius.com/artists/Orelsan
# s.pri noir                         https://genius.com/artists/Spri-noir
# plk                                      https://genius.com/artists/Plk
# damso                                  https://genius.com/artists/Damso
# dinos                                  https://genius.com/artists/Dinos
# nekfeu                                https://genius.com/artists/Nekfeu
# oboy                                    https://genius.com/artists/Oboy
# lomepal                              https://genius.com/artists/Lomepal
# sch                                      https://genius.com/artists/Sch
# roméo elvis                      https://genius.com/artists/Romeo-elvis
# niska                                  https://genius.com/artists/Niska
# hatik                                  https://genius.com/artists/Hatik
# zed yun pavarotti          https://genius.com/artists/Zed-yun-pavarotti
# pnl                                      https://genius.com/artists/Pnl
# jul                                      https://genius.com/artists/Jul
# hamza                                  https://genius.com/artists/Hamza
#
#                                                                   image  \
# artist_id
# columbine             https://images.genius.com/1fe7daf087e6825cef60...
# rohff                 https://images.genius.com/e7d85b983e15fcf9b3af...
# lunatic               https://images.genius.com/988880b2a371c8ede99a...
# jazzy bazz            https://images.genius.com/1404d03558b5bab5530a...
# suprême ntm           https://images.genius.com/949ffbea5ebe16dd1762...
# swing                 https://images.genius.com/b7403990aa1d693cfd2d...
# kery james            https://images.genius.com/74cf66f613495ab9c902...
# caballero & jeanjass  https://images.genius.com/162dab2faa69d8a7035a...
# 1995                  https://images.genius.com/0d0c589a33ca5244d534...
# luidji                https://images.genius.com/a8a0e2ed1cb27d7742f2...
# moji x sboy           https://images.genius.com/6d8e5c686e7c3224514c...
# alpha wann            https://images.genius.com/9eceb53405edce9e2226...
# zola                  https://images.genius.com/8aef51aedcdfadd5eef6...
# bu$hi                 https://images.genius.com/050576e9808baedd8ef1...
# népal                 https://images.genius.com/4a06b9304948c1278d57...
# green montana         https://images.genius.com/b1a4449b1281a51c22da...
# di-meh                https://images.genius.com/c618e1678656012159ad...
# freeze corleone       https://images.genius.com/3363b0155abaa3b46e95...
# lefa                  https://images.genius.com/c20c661812494d9b3f7c...
# booba                 https://images.genius.com/f87d62132f88bf91eee1...
# krisy                 https://images.genius.com/6400f38376f2ec97d525...
# laylow                https://images.genius.com/d9e11a197886a8795629...
# kaaris                https://images.genius.com/5c49c23c8e408fb8d863...
# makala                https://images.genius.com/3ac42be4fbca819d018c...
# vald                  https://images.genius.com/39c8b2b31afea4a29bc8...
# koba lad              https://images.genius.com/bf0af9e36f2dd292b14c...
# deen burbigo          https://images.genius.com/3b7a67109388e7135422...
# 7 jaws                https://images.genius.com/53228993bf27577b8a39...
# 13 block              https://images.genius.com/475cbda85c9a0cf007d0...
# sopico                https://images.genius.com/42014f3e25894c4f638b...
# la fouine             https://images.genius.com/85a9f2fff1af7fbc1991...
# georgio               https://images.genius.com/b7fa89dd7c4e042cfbf5...
# sneazzy               https://images.genius.com/f89e15af72c458c417a6...
# josman                https://images.genius.com/dffc429d8c62b65f4b92...
# youv dee              https://images.genius.com/1bb69d02b029f3ffb74a...
# kalash criminel       https://images.genius.com/3ec9bdee9486fdf90ad7...
# disiz la peste        https://images.genius.com/f5c4d9d28be4cae13e5e...
# bosh                  https://images.genius.com/a9e8d1f32b8e06ad760b...
# gazo                  https://images.genius.com/f9c286115fac81dcac5d...
# orelsan               https://images.genius.com/e31f6adc3dec9edafab8...
# s.pri noir            https://images.genius.com/452fb5bb6afafde98160...
# plk                   https://images.genius.com/c09cce477e2697170eb1...
# damso                 https://images.genius.com/57aa49f445bb856c82f4...
# dinos                 https://images.genius.com/591d089a09ca3b4906bb...
# nekfeu                https://images.genius.com/5f89988a816404d2f29a...
# oboy                  https://images.genius.com/252dcb722d9851a5ee8d...
# lomepal               https://images.genius.com/cf19fa33f7a1cd3b1dd9...
# sch                   https://images.genius.com/dfa1dc4028ae9d7567cd...
# roméo elvis           https://images.genius.com/bf383cc49f0c3824d72e...
# niska                 https://images.genius.com/7b9ad14cd4defcf386ac...
# hatik                 https://images.genius.com/4d36213b4fdb8ef9a77b...
# zed yun pavarotti     https://images.genius.com/ab65b042d11f12a286d3...
# pnl                   https://images.genius.com/1518f8e82d8a48060c5e...
# jul                   https://images.genius.com/3d6d65909c61ae6035e8...
# hamza                 https://images.genius.com/4e999f4c4332ed7339dc...
#
#                                                                   songs  \
# artist_id
# columbine             [{'artist_name': 'Columbine', 'artist_id': 315...
# rohff                 [{'artist_name': 'Rohff', 'artist_id': 1908, '...
# lunatic               [{'artist_name': 'Lunatic', 'artist_id': 1945,...
# jazzy bazz            [{'artist_name': 'Jazzy Bazz', 'artist_id': 13...
# suprême ntm           [{'artist_name': 'Suprême NTM', 'artist_id': 2...
# swing                 [{'artist_name': 'Swing', 'artist_id': 8444, '...
# kery james            [{'artist_name': 'Kery James', 'artist_id': 12...
# caballero & jeanjass  [{'artist_name': 'Caballero & JeanJass', 'arti...
# 1995                  [{'artist_name': '1995', 'artist_id': 12091, '...
# luidji                [{'artist_name': 'Luidji', 'artist_id': 14723,...
# moji x sboy           [{'artist_name': 'Moji x Sboy', 'artist_id': 1...
# alpha wann            [{'artist_name': 'Alpha Wann', 'artist_id': 13...
# zola                  [{'artist_name': 'Zola', 'artist_id': 1101709,...
# bu$hi                 [{'artist_name': 'BU$HI', 'artist_id': 1233575...
# népal                 [{'artist_name': 'Népal', 'artist_id': 19547, ...
# green montana         [{'artist_name': 'Green Montana', 'artist_id':...
# di-meh                [{'artist_name': 'Di-Meh', 'artist_id': 60891,...
# freeze corleone       [{'artist_name': 'Freeze Corleone', 'artist_id...
# lefa                  [{'artist_name': 'Lefa', 'artist_id': 15927, '...
# booba                 [{'artist_name': 'Booba', 'artist_id': 1282, '...
# krisy                 [{'artist_name': 'Krisy', 'artist_id': 21255, ...
# laylow                [{'artist_name': 'Laylow', 'artist_id': 308564...
# kaaris                [{'artist_name': 'Kaaris', 'artist_id': 14693,...
# makala                [{'artist_name': 'Makala', 'artist_id': 94448,...
# vald                  [{'artist_name': 'Vald', 'artist_id': 19217, '...
# koba lad              [{'artist_name': 'Koba LaD', 'artist_id': 1247...
# deen burbigo          [{'artist_name': 'Deen Burbigo', 'artist_id': ...
# 7 jaws                [{'artist_name': '7 Jaws', 'artist_id': 107813...
# 13 block              [{'artist_name': '13 Block', 'artist_id': 3270...
# sopico                [{'artist_name': 'Sopico', 'artist_id': 235193...
# la fouine             [{'artist_name': 'La Fouine', 'artist_id': 130...
# georgio               [{'artist_name': 'Georgio', 'artist_id': 21841...
# sneazzy               [{'artist_name': 'Sneazzy', 'artist_id': 13508...
# josman                [{'artist_name': 'Josman', 'artist_id': 153477...
# youv dee              [{'artist_name': 'Youv Dee', 'artist_id': 9330...
# kalash criminel       [{'artist_name': 'Kalash Criminel', 'artist_id...
# disiz la peste        [{'artist_name': 'Disiz La Peste', 'artist_id'...
# bosh                  [{'artist_name': 'Bosh', 'artist_id': 314635, ...
# gazo                  [{'artist_name': 'Gazo', 'artist_id': 23012, '...
# orelsan               [{'artist_name': 'OrelSan', 'artist_id': 1286,...
# s.pri noir            [{'artist_name': 'S.Pri Noir', 'artist_id': 15...
# plk                   [{'artist_name': 'PLK', 'artist_id': 128813, '...
# damso                 [{'artist_name': 'Damso', 'artist_id': 45855, ...
# dinos                 [{'artist_name': 'Dinos', 'artist_id': 14806, ...
# nekfeu                [{'artist_name': 'Nekfeu', 'artist_id': 13063,...
# oboy                  [{'artist_name': 'OBOY', 'artist_id': 635729, ...
# lomepal               [{'artist_name': 'Lomepal', 'artist_id': 16138...
# sch                   [{'artist_name': 'SCH', 'artist_id': 276476, '...
# roméo elvis           [{'artist_name': 'Roméo Elvis', 'artist_id': 7...
# niska                 [{'artist_name': 'Niska', 'artist_id': 234413,...
# hatik                 [{'artist_name': 'Hatik', 'artist_id': 147321,...
# zed yun pavarotti     [{'artist_name': 'Zed Yun Pavarotti', 'artist_...
# pnl                   [{'artist_name': 'PNL', 'artist_id': 335710, '...
# jul                   [{'artist_name': 'JuL', 'artist_id': 74283, 'a...
# hamza                 [{'artist_name': 'Hamza', 'artist_id': 74111, ...
#
#                       songs_count  \
# artist_id
# columbine                       9
# rohff                          13
# lunatic                         7
# jazzy bazz                     12
# suprême ntm                     7
# swing                           5
# kery james                      6
# caballero & jeanjass            1
# 1995                           20
# luidji                         15
# moji x sboy                     3
# alpha wann                     16
# zola                           18
# bu$hi                          13
# népal                          24
# green montana                  10
# di-meh                         10
# freeze corleone                15
# lefa                           25
# booba                          39
# krisy                           7
# laylow                         27
# kaaris                         28
# makala                         25
# vald                           32
# koba lad                       13
# deen burbigo                   28
# 7 jaws                         13
# 13 block                       20
# sopico                         23
# la fouine                      18
# georgio                        22
# sneazzy                        23
# josman                         18
# youv dee                       13
# kalash criminel                17
# disiz la peste                 35
# bosh                           21
# gazo                            8
# orelsan                        40
# s.pri noir                     35
# plk                            25
# damso                          50
# dinos                          31
# nekfeu                         52
# oboy                           21
# lomepal                        40
# sch                            54
# roméo elvis                    27
# niska                          33
# hatik                          38
# zed yun pavarotti              29
# pnl                            57
# jul                            41
# hamza                          36
#
#                                                                   words  \
# artist_id
# columbine             [l'enfant, sauvage, l'enfant, terrible, a, les...
# rohff                 [comme, le, décès, d, un, proche, j, viens, t,...
# lunatic               [on, n'est, pas, du, même, groupe, sanguin, pa...
# jazzy bazz            [le, soleil, commence, à, décliner, j'aimerais...
# suprême ntm           [à, mon, contact, le, hip-hop, reste, compact,...
# swing                 [perdu, dans, la, brousse, au-d'ssus, d, moi, ...
# kery james            [ecoute, de, la, fin, de, si, c, était, à, ref...
# caballero & jeanjass  [put, some, respect, on, my, name, non, non, c...
# 1995                  [j, ai, vu, les, pyramides, qui, ondulaient, l...
# luidji                [-, quand, j'ai, vraiment, besoin, du, secours...
# moji x sboy           [eh, bébé, dis, moi, c, que, t'as, dans, la, t...
# alpha wann            [j'arrive, en, mode, raptor, rappe, fort, en, ...
# zola                  [tu-tut, allô, faut, que, j'leur, dise, ces, f...
# bu$hi                 [j'les, baise, fort, j'deviens, très, carnivor...
# népal                 [kako, no, episōdo, no, matome, saigo, no, him...
# green montana         [j'ai, les, mains, pleines, de, sang, ouais, l...
# di-meh                [oh, j'écoute, banger, dans, mercedes, benz, j...
# freeze corleone       [sku, sku, sku, ekip, ekip, ekip, mms, ldo, nr...
# lefa                  [négro, si, tu, viens, d'naître, j'te, conseil...
# booba                 [the, punisher, chanchee, pas, de, grammys, pa...
# krisy                 [-, salut, krisy, -, salut, -, j'espère, que, ...
# laylow                [bienvenue, dans, le, programme, trinity, veui...
# kaaris                [s-e, s-e, s-e, oh, clic, kaaris, kaaris, --, ...
# makala                [si, j'mentais, ça, s'verrait, si, j'mentais, ...
# vald                  [bénéfice, gang-gang, bénéfice, première, pens...
# koba lad              [eh, letempsdupiano, ouh, frenchis, got, that,...
# deen burbigo          [han, pénis, taille, poney, sous, le, levi's, ...
# 7 jaws                [pourquoi, m'a-t-il, fallu, ce, temps, pourquo...
# 13 block              [shabz, beatz, nonante, appuyez, sur, le, star...
# sopico                [j'viens, de, loin, où, j, mets, mes, affaires...
# la fouine             [yeah, yeah, yeah, co-cocaïne, dans, le, jean,...
# georgio               [au, départ, y'a, mes, potes, quand, c'est, pl...
# sneazzy               [yeah, yeah, ayo, hum, dis-moi, à, quoi, tu, j...
# josman                [j, o, s, j, o, s, j, o, s, j, o, s, j, o, s, ...
# youv dee              [hey, hey, oye, tommy, dame, el, fuego, papi, ...
# kalash criminel       [db, biggie, kill, these, motherfuckers, dou, ...
# disiz la peste        [la, flemme, du, samedi, soir, sortir, c'est, ...
# bosh                  [ola, ola, ola, hey, ouh, j'suis, sur, la, pis...
# gazo                  [s, o, le, flem, hey, j'crois, en, dieu, et, m...
# orelsan               [j'suis, dans, l'premier, mario, à, chaque, fo...
# s.pri noir            [ouais, j'suis, résigné, ouais, j'suis, résign...
# plk                   [geronimo, eh, ouais, eh, pour, être, sûr, de,...
# damso                 [oui, ouh, ouh, ouh, og, oui, j'commence, à, l...
# dinos                 [yeah, yeah, j'ai, pas, la, conscience, tranqu...
# nekfeu                [konaida, tōkyō, de, atta, toki, sabishi-sōdat...
# oboy                  [tout, niquer, c't'année, j, vais, les, prendr...
# lomepal               [bruits, de, skate, le, nom, c'est, palpal, av...
# sch                   [je, vous, ai, parlé, de, sa, capacité, à, sur...
# roméo elvis           [j'suis, perdu, t'es, où, t'es, où, il, est, t...
# niska                 [c'est, l'histoire, d'un, gang, qui, en, quelq...
# hatik                 [ouais, ouais, hey, ouais, ouais, hey, mon, pa...
# zed yun pavarotti     [beauseigne, j'marche, sur, la, mer, yah, puta...
# pnl                   [ma, frappe, y, a, personne, qui, l, arrête, p...
# jul                   [que, tu, cherches, la, merde, après, tes, pap...
# hamza                 [j'faisais, partie, d'ces, gens, affamés, just...
#
#                       words_count  \
# artist_id
# columbine                    3177
# rohff                        9606
# lunatic                      4730
# jazzy bazz                   4354
# suprême ntm                  4055
# swing                        1814
# kery james                   4481
# caballero & jeanjass          884
# 1995                        11708
# luidji                       4280
# moji x sboy                  1507
# alpha wann                   9555
# zola                         7314
# bu$hi                        3917
# népal                       10568
# green montana                2895
# di-meh                       3353
# freeze corleone              7533
# lefa                         9058
# booba                       17008
# krisy                        2827
# laylow                       8964
# kaaris                      13535
# makala                       9639
# vald                        16715
# koba lad                     6093
# deen burbigo                15366
# 7 jaws                       5822
# 13 block                     8673
# sopico                      10529
# la fouine                   10082
# georgio                     12571
# sneazzy                     13227
# josman                       9519
# youv dee                     5675
# kalash criminel              8015
# disiz la peste              16376
# bosh                         7849
# gazo                         3292
# orelsan                     21409
# s.pri noir                  16029
# plk                         11821
# damso                       19804
# dinos                       13605
# nekfeu                      32215
# oboy                         7636
# lomepal                     17792
# sch                         23758
# roméo elvis                 12461
# niska                       14603
# hatik                       16151
# zed yun pavarotti           10683
# pnl                         27063
# jul                         21053
# hamza                       15092
#
#                                                            unique_words  \
# artist_id
# columbine             [l'enfant, sauvage, terrible, a, les, bras, éc...
# rohff                 [comme, le, décès, d, un, proche, j, viens, t,...
# lunatic               [on, n'est, pas, du, même, groupe, sanguin, cr...
# jazzy bazz            [le, soleil, commence, à, décliner, j'aimerais...
# suprême ntm           [à, mon, contact, le, hip-hop, reste, compact,...
# swing                 [perdu, dans, la, brousse, au-d'ssus, d, moi, ...
# kery james            [ecoute, de, la, fin, si, c, était, à, refaire...
# caballero & jeanjass  [put, some, respect, on, my, name, non, c'est,...
# 1995                  [j, ai, vu, les, pyramides, qui, ondulaient, l...
# luidji                [-, quand, j'ai, vraiment, besoin, du, secours...
# moji x sboy           [eh, bébé, dis, moi, c, que, t'as, dans, la, t...
# alpha wann            [j'arrive, en, mode, raptor, rappe, fort, déba...
# zola                  [tu-tut, allô, faut, que, j'leur, dise, ces, f...
# bu$hi                 [j'les, baise, fort, j'deviens, très, carnivor...
# népal                 [kako, no, episōdo, matome, saigo, himitsu, ni...
# green montana         [j'ai, les, mains, pleines, de, sang, ouais, l...
# di-meh                [oh, j'écoute, banger, dans, mercedes, benz, j...
# freeze corleone       [sku, ekip, mms, ldo, nrm, freeze, raël, sur, ...
# lefa                  [négro, si, tu, viens, d'naître, j'te, conseil...
# booba                 [the, punisher, chanchee, pas, de, grammys, d'...
# krisy                 [-, salut, krisy, j'espère, que, tu, es, prêt,...
# laylow                [bienvenue, dans, le, programme, trinity, veui...
# kaaris                [s-e, oh, clic, kaaris, --, poto, back, to, th...
# makala                [si, j'mentais, ça, s'verrait, dans, mes, move...
# vald                  [bénéfice, gang-gang, première, pensée, toujou...
# koba lad              [eh, letempsdupiano, ouh, frenchis, got, that,...
# deen burbigo          [han, pénis, taille, poney, sous, le, levi's, ...
# 7 jaws                [pourquoi, m'a-t-il, fallu, ce, temps, j'ai, h...
# 13 block              [shabz, beatz, nonante, appuyez, sur, le, star...
# sopico                [j'viens, de, loin, où, j, mets, mes, affaires...
# la fouine             [yeah, co-cocaïne, dans, le, jean, samy, rejoi...
# georgio               [au, départ, y'a, mes, potes, quand, c'est, pl...
# sneazzy               [yeah, ayo, hum, dis-moi, à, quoi, tu, joues, ...
# josman                [j, o, s, monnaie, sur, l'té-c', té-c', j'bois...
# youv dee              [hey, oye, tommy, dame, el, fuego, papi, yeah,...
# kalash criminel       [db, biggie, kill, these, motherfuckers, dou, ...
# disiz la peste        [la, flemme, du, samedi, soir, sortir, c'est, ...
# bosh                  [ola, hey, ouh, j'suis, sur, la, piste, de, da...
# gazo                  [s, o, le, flem, hey, j'crois, en, dieu, et, m...
# orelsan               [j'suis, dans, l'premier, mario, à, chaque, fo...
# s.pri noir            [ouais, j'suis, résigné, l'argent, d'la, résin...
# plk                   [geronimo, eh, ouais, pour, être, sûr, de, t't...
# damso                 [oui, ouh, og, j'commence, à, la, connaître, m...
# dinos                 [yeah, j'ai, pas, la, conscience, tranquille, ...
# nekfeu                [konaida, tōkyō, de, atta, toki, sabishi-sōdat...
# oboy                  [tout, niquer, c't'année, j, vais, les, prendr...
# lomepal               [bruits, de, skate, le, nom, c'est, palpal, av...
# sch                   [je, vous, ai, parlé, de, sa, capacité, à, sur...
# roméo elvis           [j'suis, perdu, t'es, où, il, est, tard, ce, s...
# niska                 [c'est, l'histoire, d'un, gang, qui, en, quelq...
# hatik                 [ouais, hey, mon, passé, peut, s'lire, dans, r...
# zed yun pavarotti     [beauseigne, j'marche, sur, la, mer, yah, puta...
# pnl                   [ma, frappe, y, a, personne, qui, l, arrête, p...
# jul                   [que, tu, cherches, la, merde, après, tes, pap...
# hamza                 [j'faisais, partie, d'ces, gens, affamés, just...
#
#                       unique_words_count  reptition_count  \
# artist_id
# columbine                           1125             2052
# rohff                               3247             6359
# lunatic                             1579             3151
# jazzy bazz                          1423             2931
# suprême ntm                         1250             2805
# swing                                551             1263
# kery james                          1351             3130
# caballero & jeanjass                 265              619
# 1995                                3509             8199
# luidji                              1258             3022
# moji x sboy                          440             1067
# alpha wann                          2663             6892
# zola                                2029             5285
# bu$hi                               1076             2841
# népal                               2901             7667
# green montana                        789             2106
# di-meh                               911             2442
# freeze corleone                     1989             5544
# lefa                                2378             6680
# booba                               4406            12602
# krisy                                725             2102
# laylow                              2211             6753
# kaaris                              3328            10207
# makala                              2356             7283
# vald                                4049            12666
# koba lad                            1475             4618
# deen burbigo                        3716            11650
# 7 jaws                              1399             4423
# 13 block                            2067             6606
# sopico                              2508             8021
# la fouine                           2390             7692
# georgio                             2968             9603
# sneazzy                             3121            10106
# josman                              2227             7292
# youv dee                            1315             4360
# kalash criminel                     1831             6184
# disiz la peste                      3725            12651
# bosh                                1782             6067
# gazo                                 736             2556
# orelsan                             4686            16723
# s.pri noir                          3436            12593
# plk                                 2511             9310
# damso                               4167            15637
# dinos                               2789            10816
# nekfeu                              6562            25653
# oboy                                1546             6090
# lomepal                             3553            14239
# sch                                 4741            19017
# roméo elvis                         2405            10056
# niska                               2779            11824
# hatik                               3071            13080
# zed yun pavarotti                   1992             8691
# pnl                                 4750            22313
# jul                                 3688            17365
# hamza                               2240            12852
#
#                       repetition_percentage
# artist_id
# columbine                         64.589235
# rohff                             66.198209
# lunatic                           66.617336
# jazzy bazz                        67.317409
# suprême ntm                       69.173859
# swing                             69.625138
# kery james                        69.850480
# caballero & jeanjass              70.022624
# 1995                              70.029040
# luidji                            70.607477
# moji x sboy                       70.802920
# alpha wann                        72.129775
# zola                              72.258682
# bu$hi                             72.529997
# népal                             72.549205
# green montana                     72.746114
# di-meh                            72.830301
# freeze corleone                   73.596177
# lefa                              73.746964
# booba                             74.094544
# krisy                             74.354439
# laylow                            75.334672
# kaaris                            75.411895
# makala                            75.557630
# vald                              75.776249
# koba lad                          75.791892
# deen burbigo                      75.816738
# 7 jaws                            75.970457
# 13 block                          76.167416
# sopico                            76.180074
# la fouine                         76.294386
# georgio                           76.390104
# sneazzy                           76.404324
# josman                            76.604685
# youv dee                          76.828194
# kalash criminel                   77.155334
# disiz la peste                    77.253298
# bosh                              77.296471
# gazo                              77.642770
# orelsan                           78.112009
# s.pri noir                        78.563853
# plk                               78.758142
# damso                             78.958796
# dinos                             79.500184
# nekfeu                            79.630607
# oboy                              79.753798
# lomepal                           80.030351
# sch                               80.044617
# roméo elvis                       80.699783
# niska                             80.969664
# hatik                             80.985697
# zed yun pavarotti                 81.353552
# pnl                               82.448361
# jul                               82.482307
# hamza                             85.157699

# %% [markdown]
# ## 4.4 Classement des artistes se répétant du moins au plus

# %%
artists.plot(
    kind="bar",
    x="name",
    y="repetition_percentage",
    figsize=(20, 10),
    xlabel="Artiste",
    label="Pourcentage de répétition"
)
# Out:
# <AxesSubplot:xlabel='Artiste'>

# %% [markdown]
# # 5. STATISTIQUES DANS LE TEMPS
# Nous récupérons également une date sur chacune des musiques, il est alors intéressant d'exploiter cette donnée afin de relever l'évolution du langage dans le temps.
#
# Comme représentation nous avons choisi de faire deux histogrammes:
# - Un premier avec comme axe x les années et en axe y la moyenne du pourcentage d'utilisation du mot **par musique** durant l'année.
#
# - Un deuxième avec comme axe x les années et en axe y le nombre de musiques utilisant ce mot durant l'année
#
# Cette façon de représenter cette donnée statistique peut toujours être contestée, il y'a effectivement plusieurs manières de faire ressortir cette donnée. Mais celle-ci à l'avantage d'être cohérente. Prenons pour exemple le mot "le", statistiquement il est juste de se dire que l'utilisation de ce mot ne varie pas d'année en année car c'est un mot que l'on peut qualifier d'indispensable pour composer un texte. Et notre méthode garantit cette cohérence. Ainsi, si un artiste utilise un mot beaucoup de fois sur une musique cela peut nous induire en erreur par exemple.
#
# Initialement notre représentation était plutôt incomplète, en axe y on représentait le pourcentage d'utilisation du mot durant toute l'année sans prendre en compte son appartenance à une certaine musique. Ce qui peut causer des erreurs d'interprétation du graphique.
#
# Cette statistique est très intéressante en dehors de l'aspect mathématique de la chose. On peut étudier, grâce à ça: l'évolution des mentalités, analyser les tendances / modes, ainsi que de traquer la création de certains mots.

# %% [markdown]
# ### Paquets utilisés

# %%
import numpy as np
import json
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as ipw
from wordcloud import WordCloud
from typing import List

# %% [markdown]
# ## 5.1 Regroupement des mots par années

# %%
songs = pd.read_json("./datas/songs.json")

songs["year"] = songs["date"].map(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S").year)

songs.sort_values("year", ascending=False, inplace=True)

songs["words"] = songs["lyrics_keywords"].map(lambda x: x.split(" "))

songs = songs.groupby("year")["lyrics_keywords"].apply(list)
songs = songs.reset_index()

def split_keyword(keywords_list: List[str]):
    return [keywords.split(" ") for keywords in keywords_list]
songs["lyrics_keywords"] = songs["lyrics_keywords"].apply(split_keyword)

songs["songs_count"] = songs["lyrics_keywords"].map(lambda x: len(x))

songs = songs[songs["year"] > 1900]

songs
# Out:
#     year                                    lyrics_keywords  songs_count
# 2   1998  [[boom, boom, bang, bad, boy, pose, ton, gun, ...            7
# 3   2000  [[hauts-de-seine, alors, comme, ça, on, veut, ...            7
# 4   2001  [[ta-ya, pa, pa-ya, hey, yo, déséquilibre, ta-...            4
# 5   2004  [[profonde, écriture, comme, faire, un, massag...            6
# 6   2005  [[garde, la, pêche, les, mcs, sont, fauchés, p...            2
# 7   2006  [[boulouloubi, boulouloubi, bordel, quand, on,...           13
# 8   2009  [[putain, plus, avance, plus, grandis, plus, c...           22
# 9   2011  [[laisser, la, trace, un, passage, éphémère, d...           21
# 10  2012  [[hé, mais, pourquoi, quand, es, petit, que, e...           30
# 11  2013  [[donne-moi, un, faible, te, ferai, un, fort, ...            7
# 12  2014  [[igo, en, bats, les, couilles, de, ta, vie, t...            4
# 13  2015  [[igo, suis, dans, mon, bat, argent, vient, et...           56
# 14  2016  [[au, départ, mes, potes, quand, est, plus, éc...           44
# 15  2017  [[oh, ouais, oh, ouais, oh, ouais, oh, ouais, ...          150
# 16  2018  [[depuis, ai, stop, les, grandes, études, jeun...          178
# 17  2019  [[vie, ai, envie, rentrer, la, maison, le, che...          250
# 18  2020  [[ah, ah, ah, ah, okay, okay, okay, okay, as, ...          321
# 19  2021  [[monnaie, sur, té-c, té-c, bois, le, jack, se...          137

# %% [markdown]
# ## 5.2 Représentations du nombre de nos musiques par année

# %%
songs.plot(
    kind="bar",
    x="year",
    y="songs_count",
    figsize=(14, 7),
    xlabel="Année",
    label="Nombre de musiques"
)
# Out:
# <AxesSubplot:xlabel='Année'>

# %% [markdown]
# ## 5.3 Affichages de l'utilisation d'un mot par années
# Ici vous pouvez simplement taper un mot afin d'afficher les deux histogrammes mentionnés au début du chapitre.

# %%
# Textbox creation
word_textbox = ipw.Text(value="", placeholder="Search word", description="Word to count:", disabled=False)

songs_count: pd.DataFrame
searched_word: str

# Here we calculate, for each songs, the percentage of usage of the word
def percentage_usage_per_song(word: str, words: List[List[str]]):
    words_list = pd.Series(words)

    def count_percentage(words: List[str]):
        words = pd.Series(words)
        return len(words[words == word]) / len(words) * 100

    percentage_usage_per_song = words_list.map(count_percentage)

    return percentage_usage_per_song

# We want to count how many songs use the word
def count_songs(percentage_usage_per_song: pd.Series):
    return len(percentage_usage_per_song[percentage_usage_per_song > 0])

# Function called when the button is clicked
def textbox_changed(word: str):
    searched_word = word
    word_searched = word.lower().strip()

    songs_count = songs

    songs_count["percentage_usage_per_song"] = songs_count["lyrics_keywords"].map(lambda x: percentage_usage_per_song(word, x))

    # We want to calculate the average of the percentage of usage for each years
    songs_count["average_usage"] = songs_count["percentage_usage_per_song"].map(lambda x: x.mean())
    songs_count["number_of_songs"] = songs_count["percentage_usage_per_song"].map(count_songs)

    fig, axes = plt.subplots(nrows=1, ncols=2)
    
    songs_count.plot.bar(
        x="year",
        y="number_of_songs",
        figsize=(25, 5),
        ax=axes[0],
        xlabel="Année",
        label="Nombre de musiques utilisant le mot"
    )

    songs_count.plot.bar(
        x="year",
        y="average_usage",
        figsize=(25, 5),
        ax=axes[1],
        color=(1, 0, 0),
        xlabel="Année",
        label="Moyenne du pourcentage d'utilisation du mot"
    )

# Button interaction
ipw.interact_manual(textbox_changed, word=word_textbox.value)
# Out:
# interactive(children=(Text(value='', description='word'), Button(description='Run Interact', style=ButtonStyle…
# <function __main__.textbox_changed(word: str)>

# %% [markdown]
# # 6. LIMITATIONS ET PERSPECTIVES
#
# La limitation principale de notre projet est évidemment sur l’échantillon de données que nous avons. Pour ce cas d’école, nous avons tout de même une bonne quantité de données pour les statistiques que nous effectuons. Néanmoins en augmentant encore le nombre de chansons de différents artistes de différentes années, les résultats pourraient être encore plus précis.
# De plus, comme dit précédemment, si on prend un exemple précis de l’affichage de l’utilisation d’un mot par années. Si un artiste utilise un mot un grand nombre de fois cela peut parfois fausser la statistique.
#
# L'amélioration la plus intéressante qui pourrait être faite est celle de comparer différents genres musicaux. Par exemple, comparer le pourcentage d’utilisation d’un mot particulier dans le rap, rock et la pop. On pourrait également comparer la variété du vocabulaire de différents artistes des différents genres pour voir dans quel style il y a le moins de répétitions de mots.
# Grâce à notre façon de calculer cette statistique, il nous est aisé d'appliquer cette amélioration. Il suffirait d’ajouter des chansons de différents styles musicaux dans le fichier qui contient tous les titres des musiques et qu’il soit aussi disponibles sur le site de Genius.
#
# Une autre amélioration envisageable serait de pouvoir ajouter directement une chanson qui sera utilisée dans les statistiques grâce à une interface intégrée au notebook. Cela augmentera beaucoup l’utilisation de notre projet pour des utilisateurs moins expérimentés.
#
# Malheureusement nous n’avons pas pu réaliser ces fonctionnalités en raison d'un manque de temps.

# %% [markdown]
# # 7. CONCLUSION
#
# En dehors de la problématique de la récupération des paroles de chansons, nous n'avons pas particulièrement rencontré de trop grosses difficultés lors de la réalisation de ce projet.
# Il nous a permis de nous familiariser avec la « transformation » de données pour les avoir dans le format souhaité. En plus de cela, on a pu avoir une première approche des outils que fournissent le langage python pour réaliser des graphiques.
#
# Nous avons pu terminer le travail dans les temps. Toutes les fonctionnalités prévues initialement ont pu être réalisées et quelques ajouts ont également été effectués. Nous aurions aimé pouvoir achever complètement le projet avant de le rendre avec les quelques améliorations citées au-dessus, mais nous sommes déjà satisfaits du résultat actuel.
#
# Pour conclure, nous espérons que nous avons pu montrer avec genyus et ses différentes statistiques, la variété et même l’évolution du vocabulaire utilisé dans le rap francophone.

# %% [markdown]
# <p align="center">
#   <br/>
#   <img src="medias/he-arc-logo.png" width="450px">
#   <br/>
#   <br/>
#   <p align="center">Haute-École Arc (Tous droits réservés)
#   </p>
#   <br/>
# </p>
